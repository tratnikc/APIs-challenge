# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
import datetime

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
output_dir = output_data_file.split('/')

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = [] #?? get country code from citipy? 

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create url
units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={api_keys.api_key}&q={city}&units={units}"

# %%
#loop thru all cities
#check if city can be found in openweathermap
#if found, add city to bucket set
#if not found, skip and continue

city = []       #response["name"]
cloudiness = [] #response["clouds"]["all"]
country = []    #response["sys"]["country"]
date = []       #response["dt"]
humidity = []   #response["main"]["humidity"]
lat = []        #response["coord"]["lat"]
lng = []        #response["coord"]["lon"]
max_temp = []   #response["main"]["temp_max"]
wind_speed = [] #response["wind"]["speed"]
sleep_interval = 55
basket_counter = 1
city_counter = 0
city_not_found = []

newline = '\n'
first_line = "Beginning Data Retrieval"
last_line = "Data Retrieval Complete"
just_line = "-------------------------------------"
not_found = "City not found... Skipping"
print(first_line)
print(just_line)
output_log = os.path.join(output_dir[0], "output_log.txt")
with open(output_log, 'w', newline='') as logfile:
    logfile.write(first_line + newline)
    logfile.write(just_line + newline)

    for x in range(len(cities)):
        query_url = f"{url}appid={api_keys.api_key}&q={cities[x]}&units={units}"
        response = requests.get(query_url).json()

        try:
            city.append(response["name"])

            try:
                country.append(response["sys"]["country"])
                date.append(response["dt"])
                humidity.append(response["main"]["humidity"])
                lat.append(response["coord"]["lat"])
                lng.append(response["coord"]["lon"])
                max_temp.append(response["main"]["temp_max"])
                wind_speed.append(response["wind"]["speed"])
                cloudiness.append(response["clouds"]["all"])

                city_counter += 1
                process_msg = f"Processing Record {city_counter} of Set {basket_counter} | {cities[x]}"
                print(process_msg)
                logfile.write(process_msg + newline)
                
                if (len(city) % 50) == 0:
                    basket_counter += 1
                    city_counter = 0
                    time.sleep(sleep_interval)

            except:
                process_msg = "Other error."
                print(process_msg)
                logfile.write(process_msg + newline)
                pass

        except:
            process_msg = f"{not_found} {cities[x]}"
            print(process_msg)
            logfile.write(process_msg + newline)
            city_not_found.append(cities[x])
            pass

    logfile.write(just_line + newline)
    logfile.write(last_line + newline)
    logfile.write(just_line + newline)
# Out:
# Beginning Data Retrieval
# -------------------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | diu
# Processing Record 3 of Set 1 | komsomolskiy
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | thompson
# Processing Record 6 of Set 1 | sao filipe
# Processing Record 7 of Set 1 | oksfjord
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | olafsvik
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | grindavik
# Processing Record 13 of Set 1 | kargopol
# Processing Record 14 of Set 1 | kijang
# Processing Record 15 of Set 1 | lorengau
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | kalamata
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | laguna
# Processing Record 21 of Set 1 | ha tinh
# Processing Record 22 of Set 1 | owando
# Processing Record 23 of Set 1 | atuona
# City not found... Skipping taolanaro
# Processing Record 24 of Set 1 | mmathubudukwane
# City not found... Skipping barbar
# City not found... Skipping borama
# Processing Record 25 of Set 1 | shilka
# Processing Record 26 of Set 1 | airai
# Processing Record 27 of Set 1 | northam
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | clyde river
# Processing Record 31 of Set 1 | omsukchan
# Processing Record 32 of Set 1 | guerrero negro
# Processing Record 33 of Set 1 | alexandria
# Processing Record 34 of Set 1 | laibin
# Processing Record 35 of Set 1 | villacarrillo
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | tasiilaq
# City not found... Skipping mys shmidta
# Processing Record 38 of Set 1 | sao joao da barra
# Processing Record 39 of Set 1 | severo-kurilsk
# City not found... Skipping barentsburg
# Processing Record 40 of Set 1 | solnechnyy
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | faanui
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | baghdad
# City not found... Skipping tsihombe
# Processing Record 47 of Set 1 | bilma
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | lebu
# Processing Record 50 of Set 1 | kruisfontein
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | portland
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | asfi
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | port hedland
# Processing Record 7 of Set 2 | danilov
# Processing Record 8 of Set 2 | haines junction
# Processing Record 9 of Set 2 | radzyn podlaski
# Processing Record 10 of Set 2 | chipinge
# Processing Record 11 of Set 2 | tynda
# Processing Record 12 of Set 2 | iqaluit
# Processing Record 13 of Set 2 | gimli
# Processing Record 14 of Set 2 | jardim
# Processing Record 15 of Set 2 | nanortalik
# Processing Record 16 of Set 2 | tiksi
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | havelock
# Processing Record 19 of Set 2 | kapit
# City not found... Skipping wulanhaote
# Processing Record 20 of Set 2 | cayenne
# Processing Record 21 of Set 2 | half moon bay
# Processing Record 22 of Set 2 | leningradskiy
# Processing Record 23 of Set 2 | chlorakas
# City not found... Skipping warqla
# Processing Record 24 of Set 2 | joshimath
# Processing Record 25 of Set 2 | selfoss
# Processing Record 26 of Set 2 | bluff
# City not found... Skipping jiddah
# Processing Record 27 of Set 2 | myitkyina
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | sao geraldo do araguaia
# Processing Record 31 of Set 2 | asosa
# City not found... Skipping sentyabrskiy
# Processing Record 32 of Set 2 | nakamura
# Processing Record 33 of Set 2 | rudnichnyy
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | saint-augustin
# Processing Record 36 of Set 2 | hami
# Processing Record 37 of Set 2 | bengkulu
# Processing Record 38 of Set 2 | byron bay
# Processing Record 39 of Set 2 | la union
# Processing Record 40 of Set 2 | qaqortoq
# City not found... Skipping illoqqortoormiut
# Processing Record 41 of Set 2 | quatre cocos
# Processing Record 42 of Set 2 | sevierville
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | cortez
# Processing Record 46 of Set 2 | ormara
# Processing Record 47 of Set 2 | rio cuarto
# Processing Record 48 of Set 2 | ruangwa
# Processing Record 49 of Set 2 | kloulklubed
# Processing Record 50 of Set 2 | linxia
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | killarney
# Processing Record 3 of Set 3 | hilo
# Processing Record 4 of Set 3 | saint anthony
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | camacha
# Processing Record 7 of Set 3 | luwuk
# Processing Record 8 of Set 3 | grand gaube
# Processing Record 9 of Set 3 | asau
# Processing Record 10 of Set 3 | mar del plata
# Processing Record 11 of Set 3 | belaya gora
# Processing Record 12 of Set 3 | quelimane
# Processing Record 13 of Set 3 | denpasar
# Processing Record 14 of Set 3 | constitucion
# Processing Record 15 of Set 3 | geraldton
# Processing Record 16 of Set 3 | tyler
# Processing Record 17 of Set 3 | bure
# Processing Record 18 of Set 3 | saskylakh
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | hammerfest
# Processing Record 21 of Set 3 | bandarbeyla
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | broome
# Processing Record 24 of Set 3 | luba
# Processing Record 25 of Set 3 | touros
# Processing Record 26 of Set 3 | kungurtug
# Processing Record 27 of Set 3 | nikolskoye
# City not found... Skipping tumannyy
# Processing Record 28 of Set 3 | orlovskiy
# Processing Record 29 of Set 3 | namatanai
# Processing Record 30 of Set 3 | carnarvon
# Processing Record 31 of Set 3 | bafra
# Processing Record 32 of Set 3 | bom jesus da lapa
# Processing Record 33 of Set 3 | saldanha
# Processing Record 34 of Set 3 | port-cartier
# Processing Record 35 of Set 3 | saint-philippe
# Processing Record 36 of Set 3 | lasa
# Processing Record 37 of Set 3 | bustamante
# Processing Record 38 of Set 3 | dunedin
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | venlo
# Processing Record 41 of Set 3 | vardo
# Processing Record 42 of Set 3 | vaini
# Processing Record 43 of Set 3 | damme
# Processing Record 44 of Set 3 | bethel
# Processing Record 45 of Set 3 | tanggu
# Processing Record 46 of Set 3 | ponta delgada
# Processing Record 47 of Set 3 | butaritari
# Processing Record 48 of Set 3 | luderitz
# Processing Record 49 of Set 3 | cherskiy
# Processing Record 50 of Set 3 | palmer
# Processing Record 1 of Set 4 | berja
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | victoria
# Processing Record 4 of Set 4 | bosaso
# Processing Record 5 of Set 4 | kiama
# Processing Record 6 of Set 4 | ust-kuyga
# Processing Record 7 of Set 4 | goderich
# Processing Record 8 of Set 4 | avondale
# Processing Record 9 of Set 4 | bintulu
# Processing Record 10 of Set 4 | kodiak
# Processing Record 11 of Set 4 | ilulissat
# Processing Record 12 of Set 4 | turtas
# Processing Record 13 of Set 4 | evensk
# Processing Record 14 of Set 4 | beloha
# Processing Record 15 of Set 4 | prince rupert
# Processing Record 16 of Set 4 | yamandu
# Processing Record 17 of Set 4 | pudozh
# Processing Record 18 of Set 4 | san cristobal
# Processing Record 19 of Set 4 | cidreira
# Processing Record 20 of Set 4 | mount isa
# Processing Record 21 of Set 4 | loreto
# Processing Record 22 of Set 4 | mocuba
# Processing Record 23 of Set 4 | koumac
# Processing Record 24 of Set 4 | richards bay
# Processing Record 25 of Set 4 | aktash
# Processing Record 26 of Set 4 | bar harbor
# Processing Record 27 of Set 4 | konskie
# Processing Record 28 of Set 4 | varna
# City not found... Skipping karaul
# Processing Record 29 of Set 4 | taos
# Processing Record 30 of Set 4 | vila velha
# City not found... Skipping belushya guba
# Processing Record 31 of Set 4 | ponta do sol
# Processing Record 32 of Set 4 | rio grande
# City not found... Skipping sorvag
# Processing Record 33 of Set 4 | brae
# Processing Record 34 of Set 4 | baker city
# Processing Record 35 of Set 4 | port blair
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | beringovskiy
# City not found... Skipping vaitupu
# City not found... Skipping kuche
# Processing Record 38 of Set 4 | koppang
# Processing Record 39 of Set 4 | bathsheba
# Processing Record 40 of Set 4 | bilibino
# Processing Record 41 of Set 4 | puerto ayora
# Processing Record 42 of Set 4 | prince albert
# Processing Record 43 of Set 4 | ericeira
# Processing Record 44 of Set 4 | jupiter
# Processing Record 45 of Set 4 | longyearbyen
# Processing Record 46 of Set 4 | chimbote
# City not found... Skipping safaqis
# Processing Record 47 of Set 4 | bubaque
# Processing Record 48 of Set 4 | amuntai
# Processing Record 49 of Set 4 | mehamn
# Processing Record 50 of Set 4 | nuevo laredo
# Processing Record 1 of Set 5 | kahului
# Processing Record 2 of Set 5 | kaitangata
# Processing Record 3 of Set 5 | fort nelson
# Processing Record 4 of Set 5 | plettenberg bay
# Processing Record 5 of Set 5 | mayor pablo lagerenza
# City not found... Skipping solovetskiy
# Processing Record 6 of Set 5 | pyay
# Processing Record 7 of Set 5 | aklavik
# Processing Record 8 of Set 5 | mao
# City not found... Skipping louisbourg
# Processing Record 9 of Set 5 | gigmoto
# Processing Record 10 of Set 5 | sorland
# Processing Record 11 of Set 5 | kudahuvadhoo
# Processing Record 12 of Set 5 | college
# Processing Record 13 of Set 5 | sassandra
# Processing Record 14 of Set 5 | moose factory
# Processing Record 15 of Set 5 | vanimo
# Processing Record 16 of Set 5 | sur
# Processing Record 17 of Set 5 | macamic
# Processing Record 18 of Set 5 | bonthe
# Processing Record 19 of Set 5 | angoche
# Processing Record 20 of Set 5 | nuuk
# Processing Record 21 of Set 5 | mareeba
# Processing Record 22 of Set 5 | tandil
# Processing Record 23 of Set 5 | tura
# Processing Record 24 of Set 5 | marystown
# City not found... Skipping mocambique
# Processing Record 25 of Set 5 | awjilah
# Processing Record 26 of Set 5 | hay river
# Processing Record 27 of Set 5 | katsuura
# Processing Record 28 of Set 5 | calvinia
# Processing Record 29 of Set 5 | mayskiy
# Processing Record 30 of Set 5 | nouadhibou
# Processing Record 31 of Set 5 | san juan
# Processing Record 32 of Set 5 | khatanga
# Processing Record 33 of Set 5 | wamba
# Processing Record 34 of Set 5 | kalabo
# Processing Record 35 of Set 5 | merta
# Processing Record 36 of Set 5 | sterling
# Processing Record 37 of Set 5 | la ronge
# Processing Record 38 of Set 5 | yar-sale
# Processing Record 39 of Set 5 | lompoc
# Processing Record 40 of Set 5 | baykit
# Processing Record 41 of Set 5 | pahrump
# Processing Record 42 of Set 5 | la rioja
# Processing Record 43 of Set 5 | kidal
# Processing Record 44 of Set 5 | sokolo
# Processing Record 45 of Set 5 | ati
# Processing Record 46 of Set 5 | bismarck
# Processing Record 47 of Set 5 | te anau
# Processing Record 48 of Set 5 | barrow
# Processing Record 49 of Set 5 | upernavik
# Processing Record 50 of Set 5 | nanakuli
# Processing Record 1 of Set 6 | alibag
# Processing Record 2 of Set 6 | shirvan
# Processing Record 3 of Set 6 | aksu
# Processing Record 4 of Set 6 | atambua
# Processing Record 5 of Set 6 | hofn
# Processing Record 6 of Set 6 | general roca
# Processing Record 7 of Set 6 | ratnagiri
# Processing Record 8 of Set 6 | kalmunai
# Processing Record 9 of Set 6 | deshnok
# Processing Record 10 of Set 6 | zabid
# Processing Record 11 of Set 6 | pecos
# Processing Record 12 of Set 6 | oranjemund
# Processing Record 13 of Set 6 | rancho palos verdes
# Processing Record 14 of Set 6 | jalu
# Processing Record 15 of Set 6 | erenhot
# Processing Record 16 of Set 6 | caravelas
# Processing Record 17 of Set 6 | bambanglipuro
# Processing Record 18 of Set 6 | mukhen
# Processing Record 19 of Set 6 | marawi
# City not found... Skipping marcona
# Processing Record 20 of Set 6 | chapleau
# Processing Record 21 of Set 6 | paamiut
# Processing Record 22 of Set 6 | villa constitucion
# Processing Record 23 of Set 6 | zykovo
# City not found... Skipping grand river south east
# Processing Record 24 of Set 6 | santiago
# Processing Record 25 of Set 6 | lekoni
# Processing Record 26 of Set 6 | cuci
# Processing Record 27 of Set 6 | jinchang
# Processing Record 28 of Set 6 | luganville
# Processing Record 29 of Set 6 | chililabombwe
# Processing Record 30 of Set 6 | san patricio
# Processing Record 31 of Set 6 | palu
# Processing Record 32 of Set 6 | roald
# City not found... Skipping nizhneyansk
# Processing Record 33 of Set 6 | presidencia roque saenz pena
# Processing Record 34 of Set 6 | yellowknife
# Processing Record 35 of Set 6 | visby
# Processing Record 36 of Set 6 | ancud
# Processing Record 37 of Set 6 | kurdzhinovo
# Processing Record 38 of Set 6 | padang
# Processing Record 39 of Set 6 | okoneshnikovo
# Processing Record 40 of Set 6 | hithadhoo
# Processing Record 41 of Set 6 | tolstoy-yurt
# Processing Record 42 of Set 6 | amberley
# Processing Record 43 of Set 6 | wanning
# City not found... Skipping umzimvubu
# Processing Record 44 of Set 6 | turukhansk
# City not found... Skipping meyungs
# Processing Record 45 of Set 6 | dwarka
# Processing Record 46 of Set 6 | hendrina
# City not found... Skipping yomitan
# Processing Record 47 of Set 6 | rawson
# Processing Record 48 of Set 6 | puerto del rosario
# Processing Record 49 of Set 6 | cascais
# Processing Record 50 of Set 6 | najran
# Processing Record 1 of Set 7 | manggar
# Processing Record 2 of Set 7 | araouane
# Processing Record 3 of Set 7 | abu samrah
# City not found... Skipping attawapiskat
# Processing Record 4 of Set 7 | kavieng
# Processing Record 5 of Set 7 | hovd
# Processing Record 6 of Set 7 | karasburg
# City not found... Skipping mrirt
# Processing Record 7 of Set 7 | lodwar
# Processing Record 8 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 7 | norman wells
# Processing Record 10 of Set 7 | san francisco
# Processing Record 11 of Set 7 | san fernando
# Processing Record 12 of Set 7 | taltal
# Processing Record 13 of Set 7 | pangnirtung
# Processing Record 14 of Set 7 | provideniya
# Processing Record 15 of Set 7 | villa union
# Processing Record 16 of Set 7 | bastia
# Processing Record 17 of Set 7 | ushibuka
# Processing Record 18 of Set 7 | kyaikkami
# Processing Record 19 of Set 7 | badiraguato
# Processing Record 20 of Set 7 | roma
# Processing Record 21 of Set 7 | muros
# Processing Record 22 of Set 7 | nelson bay
# Processing Record 23 of Set 7 | kupang
# Processing Record 24 of Set 7 | hirado
# Processing Record 25 of Set 7 | chirongui
# Processing Record 26 of Set 7 | los llanos de aridane
# Processing Record 27 of Set 7 | hastings
# Processing Record 28 of Set 7 | faro
# Processing Record 29 of Set 7 | edd
# Processing Record 30 of Set 7 | mastic beach
# Processing Record 31 of Set 7 | tak bai
# Processing Record 32 of Set 7 | fairbanks
# Processing Record 33 of Set 7 | sampit
# Processing Record 34 of Set 7 | niteroi
# Processing Record 35 of Set 7 | buluang
# Processing Record 36 of Set 7 | bozuyuk
# Processing Record 37 of Set 7 | ahipara
# Processing Record 38 of Set 7 | cockburn town
# Processing Record 39 of Set 7 | lagoa
# Processing Record 40 of Set 7 | falmouth
# Processing Record 41 of Set 7 | leninsk
# Processing Record 42 of Set 7 | skibbereen
# Processing Record 43 of Set 7 | calabozo
# Processing Record 44 of Set 7 | lafia
# Processing Record 45 of Set 7 | tomatlan
# Processing Record 46 of Set 7 | batemans bay
# Processing Record 47 of Set 7 | codrington
# Processing Record 48 of Set 7 | lethem
# Processing Record 49 of Set 7 | payyannur
# Processing Record 50 of Set 7 | port shepstone
# Processing Record 1 of Set 8 | lavrentiya
# Processing Record 2 of Set 8 | gobabis
# Processing Record 3 of Set 8 | saint-pierre
# Processing Record 4 of Set 8 | beidao
# Processing Record 5 of Set 8 | kirovskiy
# Processing Record 6 of Set 8 | itarema
# Processing Record 7 of Set 8 | wenling
# Processing Record 8 of Set 8 | kavaratti
# Processing Record 9 of Set 8 | catamarca
# Processing Record 10 of Set 8 | nishihara
# Processing Record 11 of Set 8 | mawlaik
# Processing Record 12 of Set 8 | yulara
# Processing Record 13 of Set 8 | pangai
# Processing Record 14 of Set 8 | nang rong
# Processing Record 15 of Set 8 | alofi
# Processing Record 16 of Set 8 | lufilufi
# Processing Record 17 of Set 8 | port keats
# Processing Record 18 of Set 8 | kieta
# Processing Record 19 of Set 8 | barybino
# Processing Record 20 of Set 8 | shitanjing
# Processing Record 21 of Set 8 | karratha
# Processing Record 22 of Set 8 | poum
# Processing Record 23 of Set 8 | pisco
# Processing Record 24 of Set 8 | khasan
# Processing Record 25 of Set 8 | vila
# Processing Record 26 of Set 8 | terre haute
# Processing Record 27 of Set 8 | pattoki
# Processing Record 28 of Set 8 | flinders
# City not found... Skipping burica
# Processing Record 29 of Set 8 | fare
# Processing Record 30 of Set 8 | biltine
# Processing Record 31 of Set 8 | the pas
# Processing Record 32 of Set 8 | hasaki
# City not found... Skipping vsevolodo-vilva
# Processing Record 33 of Set 8 | hazorasp
# Processing Record 34 of Set 8 | sola
# Processing Record 35 of Set 8 | sao gabriel da cachoeira
# Processing Record 36 of Set 8 | kyra
# City not found... Skipping amderma
# Processing Record 37 of Set 8 | tesanj
# Processing Record 38 of Set 8 | avera
# Processing Record 39 of Set 8 | sabha
# Processing Record 40 of Set 8 | coacoatzintla
# Processing Record 41 of Set 8 | mackay
# City not found... Skipping subaytilah
# Processing Record 42 of Set 8 | tilichiki
# Processing Record 43 of Set 8 | ixtapa
# Processing Record 44 of Set 8 | camabatela
# Processing Record 45 of Set 8 | oussouye
# Processing Record 46 of Set 8 | tessalit
# Processing Record 47 of Set 8 | sao goncalo do amarante
# Processing Record 48 of Set 8 | taywarah
# Processing Record 49 of Set 8 | kyshtovka
# Processing Record 50 of Set 8 | salinas
# City not found... Skipping gurgan
# Processing Record 1 of Set 9 | kasempa
# Processing Record 2 of Set 9 | moctezuma
# Processing Record 3 of Set 9 | narsaq
# Processing Record 4 of Set 9 | abalak
# Processing Record 5 of Set 9 | usa river
# Processing Record 6 of Set 9 | bacabac
# Processing Record 7 of Set 9 | moron
# City not found... Skipping galiwinku
# Processing Record 8 of Set 9 | conceicao do araguaia
# Processing Record 9 of Set 9 | natal
# Processing Record 10 of Set 9 | kanniyakumari
# Processing Record 11 of Set 9 | silikatnyy
# City not found... Skipping ijaki
# Processing Record 12 of Set 9 | maryville
# City not found... Skipping sidi qasim
# Processing Record 13 of Set 9 | xining
# Processing Record 14 of Set 9 | makakilo city
# Processing Record 15 of Set 9 | macenta
# Processing Record 16 of Set 9 | sungaipenuh
# Processing Record 17 of Set 9 | salinopolis
# Processing Record 18 of Set 9 | bethanien
# Processing Record 19 of Set 9 | malanje
# Processing Record 20 of Set 9 | tortoli
# Processing Record 21 of Set 9 | freetown
# Processing Record 22 of Set 9 | chapais
# Processing Record 23 of Set 9 | kamsack
# Processing Record 24 of Set 9 | fukue
# Processing Record 25 of Set 9 | mandalgovi
# Processing Record 26 of Set 9 | buala
# Processing Record 27 of Set 9 | vilyuysk
# Processing Record 28 of Set 9 | malpe
# Processing Record 29 of Set 9 | jining
# Processing Record 30 of Set 9 | antofagasta
# Processing Record 31 of Set 9 | waipawa
# Processing Record 32 of Set 9 | honningsvag
# Processing Record 33 of Set 9 | lincoln
# Processing Record 34 of Set 9 | nalut
# Processing Record 35 of Set 9 | vanavara
# City not found... Skipping bandar-e torkaman
# Processing Record 36 of Set 9 | cocobeach
# Processing Record 37 of Set 9 | iralaya
# Processing Record 38 of Set 9 | birjand
# Processing Record 39 of Set 9 | port lincoln
# Processing Record 40 of Set 9 | tucupita
# Processing Record 41 of Set 9 | palmas
# City not found... Skipping zhanatas
# Processing Record 42 of Set 9 | uruacu
# Processing Record 43 of Set 9 | newport
# Processing Record 44 of Set 9 | nouakchott
# Processing Record 45 of Set 9 | port moresby
# Processing Record 46 of Set 9 | portsoy
# Processing Record 47 of Set 9 | leon valley
# Processing Record 48 of Set 9 | lagos
# Processing Record 49 of Set 9 | yushala
# Processing Record 50 of Set 9 | lashio
# Processing Record 1 of Set 10 | caranavi
# Processing Record 2 of Set 10 | guymon
# Processing Record 3 of Set 10 | talnakh
# Processing Record 4 of Set 10 | lazaro cardenas
# Processing Record 5 of Set 10 | kihei
# Processing Record 6 of Set 10 | iraray
# Processing Record 7 of Set 10 | banda aceh
# Processing Record 8 of Set 10 | roura
# Processing Record 9 of Set 10 | praia da vitoria
# Processing Record 10 of Set 10 | de-kastri
# Processing Record 11 of Set 10 | tecoanapa
# Processing Record 12 of Set 10 | shenzhen
# Processing Record 13 of Set 10 | qui nhon
# City not found... Skipping ye
# Processing Record 14 of Set 10 | severodvinsk
# Processing Record 15 of Set 10 | puerto escondido
# Processing Record 16 of Set 10 | naze
# Processing Record 17 of Set 10 | turayf
# Processing Record 18 of Set 10 | andenes
# Processing Record 19 of Set 10 | kutum
# Processing Record 20 of Set 10 | soto la marina
# Processing Record 21 of Set 10 | marevo
# Processing Record 22 of Set 10 | morro bay
# Processing Record 23 of Set 10 | zhanaozen
# Processing Record 24 of Set 10 | boali
# Processing Record 25 of Set 10 | khuzhir
# Processing Record 26 of Set 10 | tautira
# Processing Record 27 of Set 10 | panevezys
# Processing Record 28 of Set 10 | warman
# Processing Record 29 of Set 10 | houffalize
# Processing Record 30 of Set 10 | monteagudo
# Processing Record 31 of Set 10 | shakhtinsk
# Processing Record 32 of Set 10 | moengo
# Processing Record 33 of Set 10 | aykhal
# Processing Record 34 of Set 10 | alice springs
# Processing Record 35 of Set 10 | pangkalanbuun
# Processing Record 36 of Set 10 | vostok
# City not found... Skipping samusu
# Processing Record 37 of Set 10 | westport
# Processing Record 38 of Set 10 | san jose
# Processing Record 39 of Set 10 | zenzeli
# Processing Record 40 of Set 10 | lugovoy
# City not found... Skipping paradwip
# Processing Record 41 of Set 10 | juan aldama
# Processing Record 42 of Set 10 | brigham city
# Processing Record 43 of Set 10 | xai-xai
# Processing Record 44 of Set 10 | shimoda
# Processing Record 45 of Set 10 | dingle
# Processing Record 46 of Set 10 | kathu
# Processing Record 47 of Set 10 | olinda
# Processing Record 48 of Set 10 | kachiry
# Processing Record 49 of Set 10 | batagay-alyta
# Processing Record 50 of Set 10 | sindou
# Processing Record 1 of Set 11 | durango
# Processing Record 2 of Set 11 | malkara
# Processing Record 3 of Set 11 | manacor
# Processing Record 4 of Set 11 | hambantota
# Processing Record 5 of Set 11 | rognan
# Processing Record 6 of Set 11 | lejanias
# Processing Record 7 of Set 11 | berdigestyakh
# Processing Record 8 of Set 11 | cody
# Processing Record 9 of Set 11 | cine
# Processing Record 10 of Set 11 | saint george
# Processing Record 11 of Set 11 | springdale
# Processing Record 12 of Set 11 | ningxiang
# Processing Record 13 of Set 11 | mani
# Processing Record 14 of Set 11 | dubbo
# Processing Record 15 of Set 11 | kenai
# Processing Record 16 of Set 11 | yenagoa
# Processing Record 17 of Set 11 | ugoofaaru
# Processing Record 18 of Set 11 | aiken
# Processing Record 19 of Set 11 | bangolo
# City not found... Skipping gurskoye
# Processing Record 20 of Set 11 | hot springs
# Processing Record 21 of Set 11 | zielona gora
# Processing Record 22 of Set 11 | herat
# Processing Record 23 of Set 11 | hamilton
# Processing Record 24 of Set 11 | yeppoon
# Processing Record 25 of Set 11 | esperance
# Processing Record 26 of Set 11 | novorzhev
# Processing Record 27 of Set 11 | nara
# Processing Record 28 of Set 11 | spearfish
# Processing Record 29 of Set 11 | atasu
# Processing Record 30 of Set 11 | norden
# Processing Record 31 of Set 11 | russell
# Processing Record 32 of Set 11 | kalaleh
# Processing Record 33 of Set 11 | colares
# Processing Record 34 of Set 11 | uruzgan
# Processing Record 35 of Set 11 | poughkeepsie
# Processing Record 36 of Set 11 | oga
# Processing Record 37 of Set 11 | balikpapan
# Processing Record 38 of Set 11 | great yarmouth
# Processing Record 39 of Set 11 | nacala
# Processing Record 40 of Set 11 | surt
# Processing Record 41 of Set 11 | shatalovo
# Processing Record 42 of Set 11 | mashhad
# Processing Record 43 of Set 11 | acapulco
# Processing Record 44 of Set 11 | rabaul
# Processing Record 45 of Set 11 | kirakira
# City not found... Skipping samalaeulu
# Processing Record 46 of Set 11 | agadez
# Processing Record 47 of Set 11 | saint-jean-port-joli
# Processing Record 48 of Set 11 | mogadishu
# Processing Record 49 of Set 11 | comodoro rivadavia
# Processing Record 50 of Set 11 | jackson
# Processing Record 1 of Set 12 | meulaboh
# Processing Record 2 of Set 12 | camopi
# Processing Record 3 of Set 12 | kargasok

# %%
### Convert Raw Data to DataFrame
#* Export the city data into a .csv.
#* Display the DataFrame

# %%
city_df = pd.DataFrame({"City" : city,
                       "Cloudiness" : cloudiness,
                       "Country" : country,
                       "Date" : date,
                       "Humidity" : humidity,
                       "Lat" : lat,
                       "Lng" : lng,
                       "Max Temp" : max_temp,
                       "Wind Speed" : wind_speed})

city_df.count()
# Out:
# City          553
# Cloudiness    553
# Country       553
# Date          553
# Humidity      553
# Lat           553
# Lng           553
# Max Temp      553
# Wind Speed    553
# dtype: int64

# %%
#export to csv file
output_file = os.path.join(output_dir[0], output_dir[1])
city_df.to_csv(output_file, index=False)

# %%
city_df
# Out:
#                    City  Cloudiness Country        Date  Humidity    Lat  \
# 0                Albany          97      US  1604283001        76  42.60
# 1                   Diu           0      IN  1604283066        42  20.71
# 2       Yangi Marg`ilon         100      UZ  1604282339        38  40.43
# 3               Ushuaia          75      AR  1604283067        54 -54.80
# 4              Thompson          75      CA  1604282405       100  55.74
# ..                  ...         ...     ...         ...       ...    ...
# 548  Comodoro Rivadavia           0      AR  1604283671        63 -45.87
# 549             Jackson           1      US  1604283636        34  42.42
# 550            Meulaboh         100      ID  1604283726        86   4.14
# 551              Camopi          29      GF  1604283727        93   3.17
# 552            Kargasok          97      RU  1604283727        98  59.06
#
#         Lng  Max Temp  Wind Speed
# 0    -73.97     41.00        8.46
# 1     70.98     76.32       11.27
# 2     71.72     41.00        4.70
# 3    -68.30     57.20        3.36
# 4    -97.86     21.20        3.36
# ..      ...       ...         ...
# 548  -67.50     66.20        4.14
# 549 -122.83     66.20        4.70
# 550   96.13     78.84        4.43
# 551  -52.32     74.14        2.21
# 552   80.86     29.50       10.25
#
# [553 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# create a scatter plot latitude v temperature
from datetime import datetime
dt = int(date[0])
plot_date = datetime.fromtimestamp(dt).strftime('%y/%m/%d')
x_values = city_df['Lat']
y_values = city_df['Max Temp']
fig, ax = plt.subplots(figsize=(7,7))
ax.set_autoscale_on(True)
ax.scatter(x_values, y_values)
plt.title(f"City Latitude vs Max Temperature ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_temp.png")
plt.savefig(file)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
y_hum = city_df["Humidity"]
x_lat = city_df["Lat"]
fig, ax1 = plt.subplots(figsize=(7,7))
ax1.set_autoscale_on(True)
ax1.scatter(x_lat, y_hum)
plt.title(f"City Latitude vs Humidity ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_humid.png")
plt.savefig(file)

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
y_cloud = city_df["Cloudiness"]
fig, ax2 = plt.subplots(figsize=(7,7))
ax2.set_autoscale_on(True)
ax2.scatter(x_lat, y_cloud)
plt.title(f"City Latitude vs Cloudiness ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_cloud.png")
plt.savefig(file)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
y_wind = city_df["Wind Speed"]
fig, ax3 = plt.subplots(figsize=(7,7))
ax3.set_autoscale_on(True)
ax3.scatter(x_lat, y_wind)
plt.title(f"City Latitude vs Wind Speed ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_wind.png")
plt.savefig(file)
