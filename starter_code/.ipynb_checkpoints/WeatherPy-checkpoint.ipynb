# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
import datetime

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
output_dir = output_data_file.split('/')

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = [] #?? get country code from citipy? 

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create url
units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={api_keys.api_key}&q={city}&units={units}"

# %%
# loop thru all cities, check if city can be found in openweathermap
# if found, add city to bucket set; if not found, skip and continue
# OpenWeatherMap free account allows 60 calls/min, 
# request 50 cities at a time, wait 55secs then continue loop

city = []       #response["name"]
cloudiness = [] #response["clouds"]["all"]
country = []    #response["sys"]["country"]
date = []       #response["dt"]
humidity = []   #response["main"]["humidity"]
lat = []        #response["coord"]["lat"]
lng = []        #response["coord"]["lon"]
max_temp = []   #response["main"]["temp_max"]
wind_speed = [] #response["wind"]["speed"]
city_not_found = []
sleep_interval = 55
basket_counter = 1
city_counter = 0

newline = '\n'
first_line = "Beginning Data Retrieval"
last_line = "Data Retrieval Complete"
just_line = "-------------------------------------"
not_found = "City not found... Skipping"
print(first_line)
print(just_line)
output_log = os.path.join(output_dir[0], "output_log.txt")
with open(output_log, 'w', newline='') as logfile:
    logfile.write(first_line + newline)
    logfile.write(just_line + newline)

    for x in range(len(cities)):
        query_url = f"{url}appid={api_keys.api_key}&q={cities[x]}&units={units}"
        response = requests.get(query_url).json()

        try:
            city.append(response["name"])

            try:
                country.append(response["sys"]["country"])
                date.append(response["dt"])
                humidity.append(response["main"]["humidity"])
                lat.append(response["coord"]["lat"])
                lng.append(response["coord"]["lon"])
                max_temp.append(response["main"]["temp_max"])
                wind_speed.append(response["wind"]["speed"])
                cloudiness.append(response["clouds"]["all"])

                city_counter += 1
                process_msg = f"Processing Record {city_counter} of Set {basket_counter} | {cities[x]}"
                print(process_msg)
                logfile.write(process_msg + newline)
                
                if (len(city) % 50) == 0:
                    basket_counter += 1
                    city_counter = 0
                    time.sleep(sleep_interval)

            except:
                process_msg = "Other error."
                print(process_msg)
                logfile.write(process_msg + newline)
                pass

        except:
            process_msg = f"{not_found} {cities[x]}"
            print(process_msg)
            logfile.write(process_msg + newline)
            city_not_found.append(cities[x])
            pass

    logfile.write(just_line + newline)
    logfile.write(last_line + newline)
    logfile.write(just_line + newline)
# Out:
# Beginning Data Retrieval
# -------------------------------------
# Processing Record 1 of Set 1 | hasaki
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | san cristobal
# Processing Record 4 of Set 1 | brae
# Processing Record 5 of Set 1 | dubbo
# Processing Record 6 of Set 1 | kavieng
# Processing Record 7 of Set 1 | hermanus
# City not found... Skipping taolanaro
# Processing Record 8 of Set 1 | port macquarie
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 1 | yangjiang
# Processing Record 12 of Set 1 | longyearbyen
# City not found... Skipping phumi samraong
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | komsomolskiy
# Processing Record 15 of Set 1 | cap malheureux
# Processing Record 16 of Set 1 | coahuayana
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | meulaboh
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | constitucion
# Processing Record 21 of Set 1 | orlik
# Processing Record 22 of Set 1 | boa vista
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | axim
# Processing Record 25 of Set 1 | kungurtug
# Processing Record 26 of Set 1 | sao joao da barra
# City not found... Skipping umzimvubu
# Processing Record 27 of Set 1 | namibe
# Processing Record 28 of Set 1 | sitka
# Processing Record 29 of Set 1 | yetkul
# Processing Record 30 of Set 1 | ayni
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | pontes e lacerda
# Processing Record 33 of Set 1 | petrovac
# Processing Record 34 of Set 1 | svetlogorsk
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | husavik
# Processing Record 39 of Set 1 | ponta delgada
# Processing Record 40 of Set 1 | hithadhoo
# City not found... Skipping barentsburg
# Processing Record 41 of Set 1 | chokurdakh
# Processing Record 42 of Set 1 | geraldton
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | bose
# Processing Record 45 of Set 1 | empangeni
# Processing Record 46 of Set 1 | esso
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | rikitea
# Processing Record 50 of Set 1 | airai
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | santa vitoria do palmar
# Processing Record 3 of Set 2 | bengkulu
# Processing Record 4 of Set 2 | dondo
# Processing Record 5 of Set 2 | jamestown
# City not found... Skipping amderma
# Processing Record 6 of Set 2 | hirara
# Processing Record 7 of Set 2 | kindu
# Processing Record 8 of Set 2 | ribeira grande
# Processing Record 9 of Set 2 | saint george
# Processing Record 10 of Set 2 | tuatapere
# Processing Record 11 of Set 2 | salinopolis
# City not found... Skipping marcona
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | cascais
# Processing Record 14 of Set 2 | aras
# Processing Record 15 of Set 2 | elko
# Processing Record 16 of Set 2 | kargasok
# Processing Record 17 of Set 2 | zhigansk
# City not found... Skipping illoqqortoormiut
# Processing Record 18 of Set 2 | isangel
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | haines junction
# Processing Record 21 of Set 2 | inhambane
# Processing Record 22 of Set 2 | north bend
# Processing Record 23 of Set 2 | gaomi
# Processing Record 24 of Set 2 | fortuna
# Processing Record 25 of Set 2 | walsrode
# Processing Record 26 of Set 2 | kabardinka
# Processing Record 27 of Set 2 | waiuku
# Processing Record 28 of Set 2 | ballina
# Processing Record 29 of Set 2 | prachuap khiri khan
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | sao luiz gonzaga
# City not found... Skipping zhanatas
# Processing Record 32 of Set 2 | portland
# Processing Record 33 of Set 2 | port lincoln
# City not found... Skipping bolungarvik
# Processing Record 34 of Set 2 | bereda
# Processing Record 35 of Set 2 | stornoway
# City not found... Skipping tsihombe
# Processing Record 36 of Set 2 | mana
# Processing Record 37 of Set 2 | wau
# Processing Record 38 of Set 2 | souillac
# Processing Record 39 of Set 2 | nanortalik
# Processing Record 40 of Set 2 | kapitanivka
# Processing Record 41 of Set 2 | casper
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | port elizabeth
# Processing Record 44 of Set 2 | comodoro rivadavia
# Processing Record 45 of Set 2 | ponta do sol
# Processing Record 46 of Set 2 | san juan
# City not found... Skipping karamay
# Processing Record 47 of Set 2 | sola
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 50 of Set 2 | manzanillo
# City not found... Skipping sumbawa
# Processing Record 1 of Set 3 | kenai
# Processing Record 2 of Set 3 | cherlak
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | evensk
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | leningradskiy
# Processing Record 7 of Set 3 | hobart
# Processing Record 8 of Set 3 | nouadhibou
# Processing Record 9 of Set 3 | yar-sale
# Processing Record 10 of Set 3 | tsiroanomandidy
# Processing Record 11 of Set 3 | muisne
# Processing Record 12 of Set 3 | mogadishu
# Processing Record 13 of Set 3 | cherskiy
# Processing Record 14 of Set 3 | east london
# Processing Record 15 of Set 3 | vanavara
# Processing Record 16 of Set 3 | sale
# Processing Record 17 of Set 3 | tiksi
# City not found... Skipping belushya guba
# Processing Record 18 of Set 3 | faya
# Processing Record 19 of Set 3 | luderitz
# Processing Record 20 of Set 3 | victoria
# Processing Record 21 of Set 3 | sorland
# Processing Record 22 of Set 3 | dauphin
# Processing Record 23 of Set 3 | kysyl-syr
# Processing Record 24 of Set 3 | huangyan
# Processing Record 25 of Set 3 | bathsheba
# Processing Record 26 of Set 3 | flinders
# Processing Record 27 of Set 3 | hvolsvollur
# Processing Record 28 of Set 3 | ilebo
# Processing Record 29 of Set 3 | avarua
# City not found... Skipping cheuskiny
# Processing Record 30 of Set 3 | pevek
# Processing Record 31 of Set 3 | carnarvon
# Processing Record 32 of Set 3 | pisco
# Processing Record 33 of Set 3 | koboko
# Processing Record 34 of Set 3 | sarh
# Processing Record 35 of Set 3 | labytnangi
# Processing Record 36 of Set 3 | broome
# Processing Record 37 of Set 3 | furukawa
# Processing Record 38 of Set 3 | eugene
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | hastings
# Processing Record 41 of Set 3 | maun
# Processing Record 42 of Set 3 | ilulissat
# Processing Record 43 of Set 3 | torbay
# Processing Record 44 of Set 3 | polson
# Processing Record 45 of Set 3 | tessalit
# City not found... Skipping barawe
# Processing Record 46 of Set 3 | mar del plata
# Processing Record 47 of Set 3 | porto novo
# Processing Record 48 of Set 3 | priiskovyy
# Processing Record 49 of Set 3 | shasta lake
# Processing Record 50 of Set 3 | ryotsu
# Processing Record 1 of Set 4 | ambon
# Processing Record 2 of Set 4 | wlodawa
# Processing Record 3 of Set 4 | kargil
# Processing Record 4 of Set 4 | severo-kurilsk
# Processing Record 5 of Set 4 | port-gentil
# Processing Record 6 of Set 4 | gaoual
# City not found... Skipping nizhneyansk
# Processing Record 7 of Set 4 | tuktoyaktuk
# Processing Record 8 of Set 4 | cidreira
# Processing Record 9 of Set 4 | ahuimanu
# Processing Record 10 of Set 4 | barrow
# Processing Record 11 of Set 4 | canberra
# Processing Record 12 of Set 4 | esperance
# Processing Record 13 of Set 4 | beloha
# Processing Record 14 of Set 4 | castro
# Processing Record 15 of Set 4 | nikolskoye
# Processing Record 16 of Set 4 | provideniya
# Processing Record 17 of Set 4 | clyde river
# Processing Record 18 of Set 4 | talara
# Processing Record 19 of Set 4 | alofi
# Processing Record 20 of Set 4 | bojnurd
# Processing Record 21 of Set 4 | sakakah
# Processing Record 22 of Set 4 | codrington
# Processing Record 23 of Set 4 | qaanaaq
# Processing Record 24 of Set 4 | katsuura
# Processing Record 25 of Set 4 | kokstad
# Processing Record 26 of Set 4 | san patricio
# City not found... Skipping stoyba
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | saint anthony
# Processing Record 29 of Set 4 | naze
# Processing Record 30 of Set 4 | bambous virieux
# Processing Record 31 of Set 4 | dingle
# Processing Record 32 of Set 4 | kaitangata
# Processing Record 33 of Set 4 | saint-philippe
# Processing Record 34 of Set 4 | saskylakh
# Processing Record 35 of Set 4 | cayenne
# Processing Record 36 of Set 4 | grindavik
# Processing Record 37 of Set 4 | ostrovnoy
# Processing Record 38 of Set 4 | yarada
# Processing Record 39 of Set 4 | nkhata bay
# City not found... Skipping gilgil
# Processing Record 40 of Set 4 | korla
# Processing Record 41 of Set 4 | la palma
# Processing Record 42 of Set 4 | belaya gora
# Processing Record 43 of Set 4 | goderich
# Processing Record 44 of Set 4 | tungor
# Processing Record 45 of Set 4 | lavrentiya
# Processing Record 46 of Set 4 | great yarmouth
# Processing Record 47 of Set 4 | los llanos de aridane
# City not found... Skipping tawnat
# Processing Record 48 of Set 4 | dikson
# Processing Record 49 of Set 4 | deputatskiy
# Processing Record 50 of Set 4 | araouane
# Processing Record 1 of Set 5 | letterkenny
# Processing Record 2 of Set 5 | acaponeta
# City not found... Skipping utiroa
# Processing Record 3 of Set 5 | makakilo city
# Processing Record 4 of Set 5 | nehe
# Processing Record 5 of Set 5 | sharjah
# Processing Record 6 of Set 5 | la ronge
# City not found... Skipping wahran
# Processing Record 7 of Set 5 | pangnirtung
# Processing Record 8 of Set 5 | parabel
# Processing Record 9 of Set 5 | jumla
# Processing Record 10 of Set 5 | lasa
# Processing Record 11 of Set 5 | ontario
# Processing Record 12 of Set 5 | paamiut
# Processing Record 13 of Set 5 | andenes
# Processing Record 14 of Set 5 | hilo
# Processing Record 15 of Set 5 | mount isa
# Processing Record 16 of Set 5 | bonthe
# Processing Record 17 of Set 5 | la romana
# Processing Record 18 of Set 5 | kirakira
# City not found... Skipping sentyabrskiy
# Processing Record 19 of Set 5 | srednekolymsk
# Processing Record 20 of Set 5 | olinda
# Processing Record 21 of Set 5 | okakarara
# Processing Record 22 of Set 5 | kodinar
# Processing Record 23 of Set 5 | pimentel
# Processing Record 24 of Set 5 | gravdal
# Processing Record 25 of Set 5 | vostok
# Processing Record 26 of Set 5 | charagua
# Processing Record 27 of Set 5 | tsaratanana
# Processing Record 28 of Set 5 | mufulira
# Processing Record 29 of Set 5 | banjar
# Processing Record 30 of Set 5 | volkhov
# Processing Record 31 of Set 5 | sao filipe
# Processing Record 32 of Set 5 | ugoofaaru
# Processing Record 33 of Set 5 | ulaanbaatar
# Processing Record 34 of Set 5 | iqaluit
# Processing Record 35 of Set 5 | batagay-alyta
# City not found... Skipping satitoa
# Processing Record 36 of Set 5 | adelaide
# City not found... Skipping warqla
# Processing Record 37 of Set 5 | tonj
# Processing Record 38 of Set 5 | nizhniy tsasuchey
# Processing Record 39 of Set 5 | salalah
# Processing Record 40 of Set 5 | villazon
# Processing Record 41 of Set 5 | shache
# Processing Record 42 of Set 5 | mehamn
# Processing Record 43 of Set 5 | hailar
# City not found... Skipping grand river south east
# Processing Record 44 of Set 5 | tilichiki
# Processing Record 45 of Set 5 | lucapa
# Processing Record 46 of Set 5 | mujiayingzi
# City not found... Skipping vedaranniyam
# Processing Record 47 of Set 5 | ghidfalau
# Processing Record 48 of Set 5 | gimli
# Processing Record 49 of Set 5 | auki
# Processing Record 50 of Set 5 | dutse
# Processing Record 1 of Set 6 | nybro
# Processing Record 2 of Set 6 | georgetown
# Processing Record 3 of Set 6 | moose factory
# City not found... Skipping karaul
# City not found... Skipping palabuhanratu
# Processing Record 4 of Set 6 | dunedin
# Processing Record 5 of Set 6 | gizo
# Processing Record 6 of Set 6 | sylvania
# Processing Record 7 of Set 6 | mithi
# Processing Record 8 of Set 6 | kahului
# Processing Record 9 of Set 6 | antalaha
# Processing Record 10 of Set 6 | linxia
# Processing Record 11 of Set 6 | carballo
# Processing Record 12 of Set 6 | noumea
# Processing Record 13 of Set 6 | ingham
# Processing Record 14 of Set 6 | berlevag
# Processing Record 15 of Set 6 | sungaipenuh
# Processing Record 16 of Set 6 | solnechnyy
# Processing Record 17 of Set 6 | tete
# Processing Record 18 of Set 6 | havelock
# Processing Record 19 of Set 6 | mandera
# Processing Record 20 of Set 6 | kodama
# Processing Record 21 of Set 6 | vagur
# Processing Record 22 of Set 6 | manado
# Processing Record 23 of Set 6 | tulun
# Processing Record 24 of Set 6 | bethel
# Processing Record 25 of Set 6 | lagos
# Processing Record 26 of Set 6 | neuquen
# Processing Record 27 of Set 6 | corona
# City not found... Skipping vitimskiy
# Processing Record 28 of Set 6 | luganville
# City not found... Skipping urdzhar
# Processing Record 29 of Set 6 | pacific grove
# Processing Record 30 of Set 6 | san quintin
# Processing Record 31 of Set 6 | lehigh acres
# Processing Record 32 of Set 6 | muroto
# Processing Record 33 of Set 6 | talnakh
# Processing Record 34 of Set 6 | nantucket
# Processing Record 35 of Set 6 | mecca
# Processing Record 36 of Set 6 | avanigadda
# Processing Record 37 of Set 6 | menongue
# Processing Record 38 of Set 6 | lexington
# Processing Record 39 of Set 6 | naples
# City not found... Skipping saint-pascal
# Processing Record 40 of Set 6 | acurenam
# City not found... Skipping maloshuyka
# Processing Record 41 of Set 6 | mahon
# Processing Record 42 of Set 6 | kodiak
# Processing Record 43 of Set 6 | henties bay
# Processing Record 44 of Set 6 | turukhansk
# Processing Record 45 of Set 6 | cozumel
# Processing Record 46 of Set 6 | puerto suarez
# City not found... Skipping lolua
# Processing Record 47 of Set 6 | kendari
# Processing Record 48 of Set 6 | egvekinot
# Processing Record 49 of Set 6 | hilton head island
# Processing Record 50 of Set 6 | dwarka
# City not found... Skipping malwan
# Processing Record 1 of Set 7 | umba
# Processing Record 2 of Set 7 | saint-francois
# Processing Record 3 of Set 7 | rocha
# Processing Record 4 of Set 7 | te anau
# Processing Record 5 of Set 7 | sokoto
# Processing Record 6 of Set 7 | vestmannaeyjar
# Processing Record 7 of Set 7 | abu dhabi
# Processing Record 8 of Set 7 | youkounkoun
# Processing Record 9 of Set 7 | maningrida
# Processing Record 10 of Set 7 | mareeba
# Processing Record 11 of Set 7 | aklavik
# Processing Record 12 of Set 7 | sur
# Processing Record 13 of Set 7 | curup
# Processing Record 14 of Set 7 | pindamonhangaba
# Processing Record 15 of Set 7 | mweka
# City not found... Skipping meyungs
# Processing Record 16 of Set 7 | rio grande
# City not found... Skipping tumannyy
# Processing Record 17 of Set 7 | channel-port aux basques
# Processing Record 18 of Set 7 | valdivia
# Processing Record 19 of Set 7 | itarema
# Processing Record 20 of Set 7 | shiogama
# Processing Record 21 of Set 7 | strezhevoy
# Processing Record 22 of Set 7 | yuancheng
# Processing Record 23 of Set 7 | nongpoh
# Processing Record 24 of Set 7 | port hedland
# Processing Record 25 of Set 7 | akyab
# Processing Record 26 of Set 7 | quatis
# Processing Record 27 of Set 7 | mpulungu
# Processing Record 28 of Set 7 | roald
# Processing Record 29 of Set 7 | bermeo
# Processing Record 30 of Set 7 | mafeteng
# Processing Record 31 of Set 7 | wanning
# Processing Record 32 of Set 7 | moron
# Processing Record 33 of Set 7 | pangoa
# Processing Record 34 of Set 7 | coquimbo
# Processing Record 35 of Set 7 | karasburg
# Processing Record 36 of Set 7 | hokitika
# Processing Record 37 of Set 7 | listvyagi
# City not found... Skipping tasbuget
# Processing Record 38 of Set 7 | lima
# Processing Record 39 of Set 7 | vung tau
# Processing Record 40 of Set 7 | fujin
# Processing Record 41 of Set 7 | nadym
# Processing Record 42 of Set 7 | waynesboro
# Processing Record 43 of Set 7 | kapit
# Processing Record 44 of Set 7 | okhotsk
# Processing Record 45 of Set 7 | le vauclin
# Processing Record 46 of Set 7 | houma
# Processing Record 47 of Set 7 | hartselle
# Processing Record 48 of Set 7 | betioky
# Processing Record 49 of Set 7 | hamilton
# Processing Record 50 of Set 7 | beausejour
# Processing Record 1 of Set 8 | ekhabi
# Processing Record 2 of Set 8 | liverpool
# Processing Record 3 of Set 8 | staunton
# City not found... Skipping tubruq
# Processing Record 4 of Set 8 | waverley
# Processing Record 5 of Set 8 | qasigiannguit
# Processing Record 6 of Set 8 | hualmay
# City not found... Skipping vaitupu
# Processing Record 7 of Set 8 | rawlins
# Processing Record 8 of Set 8 | vila franca do campo
# Processing Record 9 of Set 8 | mao
# Processing Record 10 of Set 8 | pemangkat
# Processing Record 11 of Set 8 | ahipara
# Processing Record 12 of Set 8 | iquitos
# Processing Record 13 of Set 8 | mount pleasant
# City not found... Skipping bacuit
# Processing Record 14 of Set 8 | goundam
# Processing Record 15 of Set 8 | kamaishi
# Processing Record 16 of Set 8 | san felipe
# Processing Record 17 of Set 8 | gejiu
# Processing Record 18 of Set 8 | lorengau
# Processing Record 19 of Set 8 | college
# Processing Record 20 of Set 8 | guerrero negro
# Processing Record 21 of Set 8 | mushie
# Processing Record 22 of Set 8 | krasnyy chikoy
# Processing Record 23 of Set 8 | changji
# Processing Record 24 of Set 8 | port blair
# Processing Record 25 of Set 8 | sinnamary
# Processing Record 26 of Set 8 | boguchany
# Processing Record 27 of Set 8 | kurali
# Processing Record 28 of Set 8 | asau
# Processing Record 29 of Set 8 | charters towers
# Processing Record 30 of Set 8 | tooele
# Processing Record 31 of Set 8 | payo
# Processing Record 32 of Set 8 | radhanpur
# Processing Record 33 of Set 8 | lata
# Processing Record 34 of Set 8 | namatanai
# Processing Record 35 of Set 8 | nemuro
# Processing Record 36 of Set 8 | vaitape
# Processing Record 37 of Set 8 | peterhead
# Processing Record 38 of Set 8 | angoram
# Processing Record 39 of Set 8 | khani
# Processing Record 40 of Set 8 | nara
# Processing Record 41 of Set 8 | kizema
# Processing Record 42 of Set 8 | narsaq
# City not found... Skipping formoso do araguaia
# Processing Record 43 of Set 8 | taiobeiras
# Processing Record 44 of Set 8 | kruisfontein
# Processing Record 45 of Set 8 | sakaiminato
# Processing Record 46 of Set 8 | kharovsk
# Processing Record 47 of Set 8 | gornopravdinsk
# Processing Record 48 of Set 8 | markova
# Processing Record 49 of Set 8 | zyryanka
# Processing Record 50 of Set 8 | jardim
# Processing Record 1 of Set 9 | ust-nera
# Processing Record 2 of Set 9 | monroe
# Processing Record 3 of Set 9 | merauke
# Processing Record 4 of Set 9 | lompoc
# Processing Record 5 of Set 9 | pakokku
# City not found... Skipping eldikan
# Processing Record 6 of Set 9 | sokoni
# Processing Record 7 of Set 9 | aykhal
# Processing Record 8 of Set 9 | camana
# Processing Record 9 of Set 9 | xingyi
# Processing Record 10 of Set 9 | tanout
# Processing Record 11 of Set 9 | grand gaube
# Processing Record 12 of Set 9 | mercedes
# City not found... Skipping mys shmidta
# Processing Record 13 of Set 9 | mackay
# Processing Record 14 of Set 9 | mount gambier
# Processing Record 15 of Set 9 | camacha
# Processing Record 16 of Set 9 | sept-iles
# Processing Record 17 of Set 9 | tignere
# City not found... Skipping shkotovo-22
# Processing Record 18 of Set 9 | udachnyy
# Processing Record 19 of Set 9 | sal rei
# Processing Record 20 of Set 9 | verkhnechusovskiye gorodki
# Processing Record 21 of Set 9 | marawi
# Processing Record 22 of Set 9 | conde
# City not found... Skipping chikoy
# Processing Record 23 of Set 9 | surin
# Processing Record 24 of Set 9 | ikom
# Processing Record 25 of Set 9 | padang
# Processing Record 26 of Set 9 | point fortin
# Processing Record 27 of Set 9 | zapolyarnyy
# Processing Record 28 of Set 9 | harper
# City not found... Skipping dzhusaly
# Processing Record 29 of Set 9 | kijang
# Processing Record 30 of Set 9 | the valley
# Processing Record 31 of Set 9 | bad doberan
# Processing Record 32 of Set 9 | ostersund
# Processing Record 33 of Set 9 | sabha
# Processing Record 34 of Set 9 | puerto carreno
# Processing Record 35 of Set 9 | shahr-e kord
# Processing Record 36 of Set 9 | taoudenni
# City not found... Skipping khormuj
# Processing Record 37 of Set 9 | geneva
# Processing Record 38 of Set 9 | pouembout
# Processing Record 39 of Set 9 | powell river
# Processing Record 40 of Set 9 | calvinia
# Processing Record 41 of Set 9 | maumere
# Processing Record 42 of Set 9 | kozhva
# Processing Record 43 of Set 9 | dodoma
# Processing Record 44 of Set 9 | anadyr
# Processing Record 45 of Set 9 | russell
# Processing Record 46 of Set 9 | tokur
# Processing Record 47 of Set 9 | gayny
# Processing Record 48 of Set 9 | kropotkin
# Processing Record 49 of Set 9 | petropavlivka
# Processing Record 50 of Set 9 | panshi
# Processing Record 1 of Set 10 | cockburn town
# Processing Record 2 of Set 10 | tambopata
# Processing Record 3 of Set 10 | yabrud
# Processing Record 4 of Set 10 | cazones
# Processing Record 5 of Set 10 | coihaique
# Processing Record 6 of Set 10 | littleton
# Processing Record 7 of Set 10 | badiraguato
# Processing Record 8 of Set 10 | brownwood
# Processing Record 9 of Set 10 | belgrade
# City not found... Skipping mentok
# Processing Record 10 of Set 10 | mingguang
# Processing Record 11 of Set 10 | chiredzi
# Processing Record 12 of Set 10 | sawakin
# Processing Record 13 of Set 10 | baracoa
# Processing Record 14 of Set 10 | sao jose da coroa grande
# Processing Record 15 of Set 10 | kalmunai
# Processing Record 16 of Set 10 | lagoa
# Processing Record 17 of Set 10 | cabedelo
# Processing Record 18 of Set 10 | muhos
# Processing Record 19 of Set 10 | faanui
# Processing Record 20 of Set 10 | pionerskiy
# Processing Record 21 of Set 10 | yomou
# Processing Record 22 of Set 10 | luanda
# Processing Record 23 of Set 10 | takoradi
# Processing Record 24 of Set 10 | olafsvik
# Processing Record 25 of Set 10 | pinega
# Processing Record 26 of Set 10 | mudon
# Processing Record 27 of Set 10 | palmer
# Processing Record 28 of Set 10 | mehndawal
# Processing Record 29 of Set 10 | socota
# Processing Record 30 of Set 10 | norman wells
# Processing Record 31 of Set 10 | nome
# Processing Record 32 of Set 10 | saint-joseph
# Processing Record 33 of Set 10 | ransang
# Processing Record 34 of Set 10 | sokolow podlaski
# Processing Record 35 of Set 10 | tabou
# Processing Record 36 of Set 10 | sydney
# Processing Record 37 of Set 10 | hervey bay
# Processing Record 38 of Set 10 | hami
# Processing Record 39 of Set 10 | quatre cocos
# Processing Record 40 of Set 10 | punta alta
# Processing Record 41 of Set 10 | sao gabriel da cachoeira
# City not found... Skipping sorvag
# Processing Record 42 of Set 10 | bilma
# Processing Record 43 of Set 10 | urucui
# Processing Record 44 of Set 10 | pangody
# Processing Record 45 of Set 10 | beringovskiy
# Processing Record 46 of Set 10 | burgeo
# Processing Record 47 of Set 10 | yulara
# Processing Record 48 of Set 10 | nhulunbuy
# Processing Record 49 of Set 10 | nagato
# Processing Record 50 of Set 10 | novyy urgal
# Processing Record 1 of Set 11 | kitimat
# Processing Record 2 of Set 11 | samarai
# Processing Record 3 of Set 11 | shingu
# Processing Record 4 of Set 11 | cilegon
# Processing Record 5 of Set 11 | voi
# Processing Record 6 of Set 11 | baculin
# Processing Record 7 of Set 11 | brewster
# Processing Record 8 of Set 11 | bintulu
# Processing Record 9 of Set 11 | labuhan
# Processing Record 10 of Set 11 | baruun-urt
# Processing Record 11 of Set 11 | hurghada
# Processing Record 12 of Set 11 | klyuchi
# Processing Record 13 of Set 11 | ishigaki
# Processing Record 14 of Set 11 | puerto escondido
# Processing Record 15 of Set 11 | yuksekova
# Processing Record 16 of Set 11 | belmonte
# Processing Record 17 of Set 11 | agadez
# Processing Record 18 of Set 11 | san jose
# Processing Record 19 of Set 11 | bialogard
# Processing Record 20 of Set 11 | raahe
# Processing Record 21 of Set 11 | ancud
# Processing Record 22 of Set 11 | mosquera
# Processing Record 23 of Set 11 | krasnoselkup
# Processing Record 24 of Set 11 | mangrol
# Processing Record 25 of Set 11 | soderhamn
# Processing Record 26 of Set 11 | sayyan
# Processing Record 27 of Set 11 | kununurra
# City not found... Skipping labutta
# Processing Record 28 of Set 11 | sonoita
# Processing Record 29 of Set 11 | kaeo
# Processing Record 30 of Set 11 | korfovskiy
# City not found... Skipping samusu
# Processing Record 31 of Set 11 | salmas
# Processing Record 32 of Set 11 | anju
# Processing Record 33 of Set 11 | atar
# Processing Record 34 of Set 11 | riyadh
# Processing Record 35 of Set 11 | ligayan
# Processing Record 36 of Set 11 | davila
# City not found... Skipping toliary
# Processing Record 37 of Set 11 | valparaiso
# Processing Record 38 of Set 11 | chirongui
# Processing Record 39 of Set 11 | la serena
# Processing Record 40 of Set 11 | mnogovershinnyy
# Processing Record 41 of Set 11 | saint-pierre
# Processing Record 42 of Set 11 | jining
# Processing Record 43 of Set 11 | vardo
# Processing Record 44 of Set 11 | chicama

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create city data frame
city_df = pd.DataFrame({"City" : city,
                       "Cloudiness" : cloudiness,
                       "Country" : country,
                       "Date" : date,
                       "Humidity" : humidity,
                       "Lat" : lat,
                       "Lng" : lng,
                       "Max Temp" : max_temp,
                       "Wind Speed" : wind_speed})

city_df.count()
# Out:
# City          544
# Cloudiness    544
# Country       544
# Date          544
# Humidity      544
# Lat           544
# Lng           544
# Max Temp      544
# Wind Speed    544
# dtype: int64

# %%
#export to csv file
output_file = os.path.join(output_dir[0], output_dir[1])
city_df.to_csv(output_file, index=True)

# %%
city_df
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0             Hasaki          75      JP  1604285907        73  35.73  140.83
# 1            Ushuaia          75      AR  1604285660        54 -54.80  -68.30
# 2      San Cristobal          99      VE  1604285992        92   7.77  -72.22
# 3               Brae          90      GB  1604285845        81  60.40   -1.35
# 4              Dubbo          43      AU  1604285993        33 -32.25  148.62
# ..               ...         ...     ...         ...       ...    ...     ...
# 539  Mnogovershinnyy         100      RU  1604286607       100  53.94  139.92
# 540     Saint-Pierre          90      RE  1604286608        64 -21.34   55.48
# 541           Jining           0      CN  1604286312        28  35.41  116.58
# 542            Vardø         100      NO  1604286608        81  70.37   31.11
# 543          Chicama          75      PE  1604286608        82  -7.84  -79.15
#
#      Max Temp  Wind Speed
# 0       71.60       13.87
# 1       57.20        4.70
# 2       66.63        2.08
# 3       50.00       32.21
# 4       77.00       12.75
# ..        ...         ...
# 539     34.90        3.11
# 540     69.80        4.70
# 541     63.63       13.18
# 542     44.69       28.16
# 543     61.88        5.66
#
# [544 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# create a scatter plot latitude v temperature
from datetime import datetime
dt = int(date[0])
plot_date = datetime.fromtimestamp(dt).strftime('%y/%m/%d')
x_lat = city_df['Lat']
y_temp = city_df['Max Temp']
fig, ax = plt.subplots(figsize=(7,7))
ax.set_autoscale_on(True)
ax.scatter(x_lat, y_temp)
plt.title(f"City Latitude vs Max Temperature ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_temp.png")
plt.savefig(file)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
y_hum = city_df["Humidity"]

fig, ax1 = plt.subplots(figsize=(7,7))
ax1.set_autoscale_on(True)
ax1.scatter(x_lat, y_hum)
plt.title(f"City Latitude vs Humidity ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_humid.png")
plt.savefig(file)

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
y_cloud = city_df["Cloudiness"]
fig, ax2 = plt.subplots(figsize=(7,7))
ax2.set_autoscale_on(True)
ax2.scatter(x_lat, y_cloud)
plt.title(f"City Latitude vs Cloudiness ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_cloud.png")
plt.savefig(file)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
y_wind = city_df["Wind Speed"]
fig, ax3 = plt.subplots(figsize=(7,7))
ax3.set_autoscale_on(True)
ax3.scatter(x_lat, y_wind)
plt.title(f"City Latitude vs Wind Speed ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_wind.png")
plt.savefig(file)
