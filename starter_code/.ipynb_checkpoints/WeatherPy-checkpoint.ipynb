# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
output_dir = output_data_file.split('/')

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = [] #?? get country code from citipy? 

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create url
units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={api_keys.api_key}&q={city}&units={units}"

# %%
city = []       #response["name"]
cloudiness = [] #response["clouds"]["all"]
country = []    #response["sys"]["country"]
date = []       #response["dt"]
humidity = []   #response["main"]["humidity"]
lat = []        #response["coord"]["lat"]
lng = []        #response["coord"]["lon"]
max_temp = []   #response["main"]["temp_max"]
wind_speed = [] #response["wind"]["speed"]
sleep_interval = 55
basket_counter = 1
city_counter = 0
city_not_found = []
#loop thru all cities
#check if city can be found in openweathermap
#if found, add city to bucket set
#if not found, skip and continue
import datetime
import time

print(datetime.datetime.now())
newline = '\n'
first_line = "Beginning Data Retrieval"
last_line = "Data Retrieval Complete"
just_line = "-------------------------------------"
not_found = "City not found... Skipping"
output_log = os.path.join(output_dir[0], "output_log.txt")
with open(output_log, 'w', newline='') as logfile:
    logfile.write(first_line + newline)
    logfile.write(just_line + newline)

    for x in range(50): #range(len(cities)):
        query_url = f"{url}appid={api_keys.api_key}&q={cities[x]}&units={units}"
        print(query_url)
        response = requests.get(query_url).json()

        try:
            city.append(response["name"])

            try:
                country.append(response["sys"]["country"])
                date.append(response["dt"])
                humidity.append(response["main"]["humidity"])
                lat.append(response["coord"]["lat"])
                lng.append(response["coord"]["lon"])
                max_temp.append(response["main"]["temp_max"])
                wind_speed.append(response["wind"]["speed"])
                cloudiness.append(response["clouds"]["all"])

                city_counter += 1
                process_msg = f"Processing Record {city_counter} of Set {basket_counter} | {cities[x]}"
                logfile.write(process_msg + newline)
                
                print(process_msg)
                print(len(city) % 50)
                if (len(city) % 50) == 0:
                    basket_counter += 1
                    city_counter = 0
                    time.sleep(sleep_interval)

            except:
                logfile.write("Other error." + newline)
                pass

        except:
            logfile.write(not_found + newline)
            city_not_found.append(cities[x])
            pass

    logfile.write(just_line + newline)
    logfile.write(last_line + newline)
    logfile.write(just_line + newline)
        
print(datetime.datetime.now())
# Out:
# 2020-11-01 18:02:45.419259
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kerman&units=imperial
# Processing Record 1 of Set 1 | kerman
# 1
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=prince rupert&units=imperial
# Processing Record 2 of Set 1 | prince rupert
# 2
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=qaanaaq&units=imperial
# Processing Record 3 of Set 1 | qaanaaq
# 3
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ushuaia&units=imperial
# Processing Record 4 of Set 1 | ushuaia
# 4
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=punta arenas&units=imperial
# Processing Record 5 of Set 1 | punta arenas
# 5
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mataura&units=imperial
# Processing Record 6 of Set 1 | mataura
# 6
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port alfred&units=imperial
# Processing Record 7 of Set 1 | port alfred
# 7
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=castro&units=imperial
# Processing Record 8 of Set 1 | castro
# 8
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rikitea&units=imperial
# Processing Record 9 of Set 1 | rikitea
# 9
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=one hundred mile house&units=imperial
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=thompson&units=imperial
# Processing Record 10 of Set 1 | thompson
# 10
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=khatanga&units=imperial
# Processing Record 11 of Set 1 | khatanga
# 11
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=carballo&units=imperial
# Processing Record 12 of Set 1 | carballo
# 12
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=atlantic city&units=imperial
# Processing Record 13 of Set 1 | atlantic city
# 13
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=busselton&units=imperial
# Processing Record 14 of Set 1 | busselton
# 14
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hilo&units=imperial
# Processing Record 15 of Set 1 | hilo
# 15
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kysyl-syr&units=imperial
# Processing Record 16 of Set 1 | kysyl-syr
# 16
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sentyabrskiy&units=imperial
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=barrow&units=imperial
# Processing Record 17 of Set 1 | barrow
# 17
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=pevek&units=imperial
# Processing Record 18 of Set 1 | pevek
# 18
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=butaritari&units=imperial
# Processing Record 19 of Set 1 | butaritari
# 19
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=jamestown&units=imperial
# Processing Record 20 of Set 1 | jamestown
# 20
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=shellbrook&units=imperial
# Processing Record 21 of Set 1 | shellbrook
# 21
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tiksi&units=imperial
# Processing Record 22 of Set 1 | tiksi
# 22
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hualmay&units=imperial
# Processing Record 23 of Set 1 | hualmay
# 23
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=waslala&units=imperial
# Processing Record 24 of Set 1 | waslala
# 24
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=srednekolymsk&units=imperial
# Processing Record 25 of Set 1 | srednekolymsk
# 25
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=haines junction&units=imperial
# Processing Record 26 of Set 1 | haines junction
# 26
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bluff&units=imperial
# Processing Record 27 of Set 1 | bluff
# 27
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ahuimanu&units=imperial
# Processing Record 28 of Set 1 | ahuimanu
# 28
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=provideniya&units=imperial
# Processing Record 29 of Set 1 | provideniya
# 29
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=maldonado&units=imperial
# Processing Record 30 of Set 1 | maldonado
# 30
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=zonguldak&units=imperial
# Processing Record 31 of Set 1 | zonguldak
# 31
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=new norfolk&units=imperial
# Processing Record 32 of Set 1 | new norfolk
# 32
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=muros&units=imperial
# Processing Record 33 of Set 1 | muros
# 33
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hermanus&units=imperial
# Processing Record 34 of Set 1 | hermanus
# 34
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bethel&units=imperial
# Processing Record 35 of Set 1 | bethel
# 35
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=marawi&units=imperial
# Processing Record 36 of Set 1 | marawi
# 36
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=san cristobal&units=imperial
# Processing Record 37 of Set 1 | san cristobal
# 37
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port-cartier&units=imperial
# Processing Record 38 of Set 1 | port-cartier
# 38
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=zhicheng&units=imperial
# Processing Record 39 of Set 1 | zhicheng
# 39
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=avarua&units=imperial
# Processing Record 40 of Set 1 | avarua
# 40
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saskylakh&units=imperial
# Processing Record 41 of Set 1 | saskylakh
# 41
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=altamira&units=imperial
# Processing Record 42 of Set 1 | altamira
# 42
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nanortalik&units=imperial
# Processing Record 43 of Set 1 | nanortalik
# 43
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint-joseph&units=imperial
# Processing Record 44 of Set 1 | saint-joseph
# 44
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tolaga bay&units=imperial
# Processing Record 45 of Set 1 | tolaga bay
# 45
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mys shmidta&units=imperial
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port blair&units=imperial
# Processing Record 46 of Set 1 | port blair
# 46
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=yellowknife&units=imperial
# Processing Record 47 of Set 1 | yellowknife
# 47
# 2020-11-01 18:02:49.343306

# %%
len(cities)
len(countries)
len(city)
city_not_found
cloudiness
country 
date
humidity
lat
lng
len(max_temp)
#len(wind_speed)
# Out:
# 47

# %%
### Convert Raw Data to DataFrame
* Export the city data into a .csv.
* Display the DataFrame

# %%
city_df = pd.DataFrame({"City" : city,
                       "Cloudiness" : cloudiness,
                       "Country" : country,
                       "Date" : date,
                       "Humidity" : humidity,
                       "Lat" : lat,
                       "Lng" : lng,
                       "Max Temp" : max_temp,
                       "Wind Speed" : wind_speed})

city_df.count()
# Out:
# City          47
# Cloudiness    47
# Country       47
# Date          47
# Humidity      47
# Lat           47
# Lng           47
# Max Temp      47
# Wind Speed    47
# dtype: int64

# %%
#export to csv file
output_file = os.path.join(output_dir[0], output_dir[1])
city_df.to_csv(output_file, index=False)

# %%
city_df
# Out:
#                          City  Cloudiness Country        Date  Humidity  \
# 0                      Kerman           0      IR  1604263974        22
# 1               Prince Rupert          90      CA  1604263974        87
# 2                     Qaanaaq           0      GL  1604263974        74
# 31 -42.78  147.06     60.01        1.01
# 32  42.78   -9.06     66.00       18.99
# 33 -34.42   19.23     63.00        4.00
# 34  41.37  -73.41     50.00        8.19
# 35   8.00  124.29     73.99        1.99
# 36   7.77  -72.22     86.00        4.70
# 37  50.03  -66.87     37.40        4.70
# 38  30.30  111.50     55.99        5.17
# 39 -21.21 -159.78     78.80       18.34
# 40  71.92  114.08    -10.07        9.60
# 41  -3.20  -52.21     95.00        6.93
# 42  60.14  -45.24     30.38       30.40
# 43 -21.37   55.62     68.00        6.93
# 44 -38.37  178.30     66.85        4.16
# 45  11.67   92.75     79.97        3.89
# 46  62.46 -114.35     17.60        8.05

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#create a data frame from city, lat, and max temp
from datetime import datetime
weather_dict = {"City" : city,
               "lat" : lat,
               "temp" : max_temp}
weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#                          City    lat   temp
# 0                      Kerman  30.28  44.60
# 1               Prince Rupert  54.32  55.40
# 2                     Qaanaaq  77.48   1.29
# 3                     Ushuaia -54.80  57.20
# 4                Punta Arenas -53.15  51.80
# 5                     Mataura -46.19  48.99
# 6                 Port Alfred -33.59  65.73
# 7                      Castro -24.79  60.44
# 8                     Rikitea -23.12  74.41
# 9                    Thompson  55.74  23.00
# 10                   Khatanga  71.97   3.38
# 11                   Carballo  43.21  66.20
# 12              Atlantic City  39.36  59.00
# 13                  Busselton -33.65  55.00
# 14                       Hilo  19.73  82.00
# 15                  Kysyl-Syr  63.90  -2.65
# 16                     Barrow  71.29  28.40
# 17                      Pevek  69.70  15.60
# 18                 Butaritari   3.07  81.93
# 19                  Jamestown  42.10  37.99
# 20                 Shellbrook  53.22  46.40
# 21                      Tiksi  71.69  -6.30
# 22                    Hualmay -11.10  67.17
# 23                    Waslala  13.23  71.60
# 24              Srednekolymsk  67.45  -4.59
# 25            Haines Junction  60.75  12.20
# 26                      Bluff -46.60  48.99
# 27                  ‘Āhuimanu  21.44  82.40
# 28                Provideniya  64.38  19.40
# 29  Departamento de Maldonado -34.67  64.99
# 30                  Zonguldak  41.25  42.89
# 31                New Norfolk -42.78  60.01
# 32                      Muros  42.78  66.00
# 33                   Hermanus -34.42  63.00
# 34                     Bethel  41.37  50.00
# 35                     Marawi   8.00  73.99
# 36              San Cristobal   7.77  86.00
# 37               Port-Cartier  50.03  37.40
# 38                   Zhicheng  30.30  55.99
# 39                     Avarua -21.21  78.80
# 40                  Saskylakh  71.92 -10.07
# 41                   Altamira  -3.20  95.00
# 42                 Nanortalik  60.14  30.38
# 43               Saint-Joseph -21.37  68.00
# 44                 Tolaga Bay -38.37  66.85
# 45                 Port Blair  11.67  79.97
# 46                Yellowknife  62.46  17.60

# %%
# create a scatter plot latitude v temperature
from datetime import datetime
dt = int(date[0])
plot_date = datetime.fromtimestamp(dt).strftime('%y/%m/%d')
x_values = weather_data['lat']
y_values = weather_data['temp']
fig, ax = plt.subplots(figsize=(7,7))
ax.set_autoscale_on(True)
ax.scatter(x_values, y_values)
plt.title(f"City Latitude vs Max Temperature ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
y_hum = city_df["Humidity"]
x_lat = city_df["Lat"]
fig, ax1 = plt.subplots(figsize=(7,7))
ax1.set_autoscale_on(True)
ax1.scatter(x_lat, y_hum)
plt.title(f"City Latitude vs Humidity ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
y_cloud = city_df["Cloudiness"]
fig, ax2 = plt.subplots(figsize=(7,7))
ax2.set_autoscale_on(True)
ax2.scatter(x_lat, y_hum)
plt.title(f"City Latitude vs Cloudiness ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
