# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
output_dir = output_data_file.split('/')

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = [] #?? get country code from citipy? 

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create url
units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={api_keys.api_key}&q={city}&units={units}"

# %%
# loop thru all cities, check if city can be found in openweathermap
# if found, add city to bucket set; if not found, skip and continue
# OpenWeatherMap free account allows 60 calls/min, 
# request 50 cities at a time, wait 55secs then continue loop

city = []       #response["name"]
cloudiness = [] #response["clouds"]["all"]
country = []    #response["sys"]["country"]
date = []       #response["dt"]
humidity = []   #response["main"]["humidity"]
lat = []        #response["coord"]["lat"]
lng = []        #response["coord"]["lon"]
max_temp = []   #response["main"]["temp_max"]
wind_speed = [] #response["wind"]["speed"]
city_not_found = []
sleep_interval = 0

basket_counter = 1
city_counter = 0

newline = '\n'
first_line = "Beginning Data Retrieval"
last_line = "Data Retrieval Complete"
just_line = "-------------------------------------"
not_found = "City not found... Skipping"
print(first_line)
print(just_line)
output_log = os.path.join(output_dir[0], "output_log.txt")
with open(output_log, 'w', newline='') as logfile:
    logfile.write(first_line + newline)
    logfile.write(just_line + newline)
    
    start_time = time.time()
    
    for x in range(len(cities)):

        query_url = f"{url}appid={api_keys.api_key}&q={cities[x]}&units={units}"
        
        response = requests.get(query_url).json()

        try:
            city.append(response["name"])

            try:
                country.append(response["sys"]["country"])
                date.append(response["dt"])
                humidity.append(response["main"]["humidity"])
                lat.append(response["coord"]["lat"])
                lng.append(response["coord"]["lon"])
                max_temp.append(response["main"]["temp_max"])
                wind_speed.append(response["wind"]["speed"])
                cloudiness.append(response["clouds"]["all"])

                city_counter += 1
                process_msg = f"Processing Record {city_counter} of Set {basket_counter} | {cities[x]}"
                print(process_msg)
                print(query_url)
                logfile.write(process_msg + newline)
                logfile.write(query_url + newline)
                
                if (len(city) % 50) == 0:
                    sleep_interval = time.time() - start_time
                    basket_counter += 1
                    city_counter = 0
                    time.sleep(60 - sleep_interval)
                    start_time = time.time()

            except:
                process_msg = "Other error."
                print(process_msg)
                logfile.write(process_msg + newline)
                pass

        except:
            process_msg = f"{not_found} {cities[x]}"
            print(process_msg)
            logfile.write(process_msg + newline)
            city_not_found.append(cities[x])
            pass

    logfile.write(just_line + newline)
    logfile.write(last_line + newline)
    logfile.write(just_line + newline)
# Out:
# Beginning Data Retrieval
# -------------------------------------
# Processing Record 1 of Set 1 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=san cristobal&units=imperial
# Processing Record 2 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=avarua&units=imperial
# Processing Record 3 of Set 1 | vao
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vao&units=imperial
# City not found... Skipping illoqqortoormiut
# Processing Record 4 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=albany&units=imperial
# Processing Record 5 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=butaritari&units=imperial
# Processing Record 6 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=khatanga&units=imperial
# Processing Record 7 of Set 1 | winnemucca
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=winnemucca&units=imperial
# City not found... Skipping marcona
# Processing Record 8 of Set 1 | ouango
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ouango&units=imperial
# Processing Record 9 of Set 1 | arsenyev
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=arsenyev&units=imperial
# Processing Record 10 of Set 1 | jogindarnagar
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=jogindarnagar&units=imperial
# Processing Record 11 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bredasdorp&units=imperial
# Processing Record 12 of Set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=severo-kurilsk&units=imperial
# Processing Record 13 of Set 1 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lompoc&units=imperial
# Processing Record 14 of Set 1 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=pangnirtung&units=imperial
# Processing Record 15 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hilo&units=imperial
# City not found... Skipping attawapiskat
# Processing Record 16 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=chokurdakh&units=imperial
# Processing Record 17 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=punta arenas&units=imperial
# Processing Record 18 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rikitea&units=imperial
# Processing Record 19 of Set 1 | cobija
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cobija&units=imperial
# Processing Record 20 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=yellowknife&units=imperial
# Processing Record 21 of Set 1 | flin flon
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=flin flon&units=imperial
# Processing Record 22 of Set 1 | magistralnyy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=magistralnyy&units=imperial
# Processing Record 23 of Set 1 | dongkan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=dongkan&units=imperial
# City not found... Skipping mys shmidta
# City not found... Skipping taolanaro
# Processing Record 24 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kapaa&units=imperial
# Processing Record 25 of Set 1 | grafton
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=grafton&units=imperial
# Processing Record 26 of Set 1 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=victoria&units=imperial
# Processing Record 27 of Set 1 | quelimane
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=quelimane&units=imperial
# Processing Record 28 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cherskiy&units=imperial
# Processing Record 29 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vaini&units=imperial
# Processing Record 30 of Set 1 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=havre-saint-pierre&units=imperial
# Processing Record 31 of Set 1 | san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=san quintin&units=imperial
# Processing Record 32 of Set 1 | chapais
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=chapais&units=imperial
# Processing Record 33 of Set 1 | aykhal
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=aykhal&units=imperial
# Processing Record 34 of Set 1 | jiangyou
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=jiangyou&units=imperial
# Processing Record 35 of Set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ponta do sol&units=imperial
# Processing Record 36 of Set 1 | puerto lempira
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=puerto lempira&units=imperial
# Processing Record 37 of Set 1 | bani
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bani&units=imperial
# Processing Record 38 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ushuaia&units=imperial
# Processing Record 39 of Set 1 | maragogi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=maragogi&units=imperial
# Processing Record 40 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=qaanaaq&units=imperial
# City not found... Skipping palabuhanratu
# Processing Record 41 of Set 1 | port blair
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port blair&units=imperial
# Processing Record 42 of Set 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bengkulu&units=imperial
# Processing Record 43 of Set 1 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=oranjemund&units=imperial
# Processing Record 44 of Set 1 | kalabo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kalabo&units=imperial
# Processing Record 45 of Set 1 | morondava
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=morondava&units=imperial
# City not found... Skipping tsihombe
# Processing Record 46 of Set 1 | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=constitucion&units=imperial
# Processing Record 47 of Set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=torbay&units=imperial
# Processing Record 48 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bluff&units=imperial
# Processing Record 49 of Set 1 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=touros&units=imperial
# Processing Record 50 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=puerto ayora&units=imperial
# Processing Record 1 of Set 2 | tahta
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tahta&units=imperial
# Processing Record 2 of Set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tuktoyaktuk&units=imperial
# Processing Record 3 of Set 2 | tabou
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tabou&units=imperial
# Processing Record 4 of Set 2 | pontes e lacerda
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=pontes e lacerda&units=imperial
# Processing Record 5 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port alfred&units=imperial
# City not found... Skipping halalo
# City not found... Skipping saleaula
# Processing Record 6 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hobart&units=imperial
# Processing Record 7 of Set 2 | sabirabad
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sabirabad&units=imperial
# Processing Record 8 of Set 2 | kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kasongo-lunda&units=imperial
# Processing Record 9 of Set 2 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=barrow&units=imperial
# Processing Record 10 of Set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nikolskoye&units=imperial
# City not found... Skipping karkaralinsk
# City not found... Skipping nizhneyansk
# Processing Record 11 of Set 2 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=umm lajj&units=imperial
# Processing Record 12 of Set 2 | toropets
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=toropets&units=imperial
# Processing Record 13 of Set 2 | mao
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mao&units=imperial
# Processing Record 14 of Set 2 | astileu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=astileu&units=imperial
# Processing Record 15 of Set 2 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=provideniya&units=imperial
# Processing Record 16 of Set 2 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lorengau&units=imperial
# Processing Record 17 of Set 2 | huarmey
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=huarmey&units=imperial
# Processing Record 18 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cape town&units=imperial
# Processing Record 19 of Set 2 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mahibadhoo&units=imperial
# Processing Record 20 of Set 2 | college
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=college&units=imperial
# Processing Record 21 of Set 2 | paamiut
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=paamiut&units=imperial
# Processing Record 22 of Set 2 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cidreira&units=imperial
# Processing Record 23 of Set 2 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=leningradskiy&units=imperial
# Processing Record 24 of Set 2 | den helder
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=den helder&units=imperial
# Processing Record 25 of Set 2 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vila velha&units=imperial
# Processing Record 26 of Set 2 | seoul
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=seoul&units=imperial
# Processing Record 27 of Set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=pevek&units=imperial
# Processing Record 28 of Set 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bethel&units=imperial
# Processing Record 29 of Set 2 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mataura&units=imperial
# Processing Record 30 of Set 2 | sola
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sola&units=imperial
# Processing Record 31 of Set 2 | ruston
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ruston&units=imperial
# Processing Record 32 of Set 2 | ha tinh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ha tinh&units=imperial
# Processing Record 33 of Set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=atuona&units=imperial
# Processing Record 34 of Set 2 | asmara
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=asmara&units=imperial
# Processing Record 35 of Set 2 | rawson
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rawson&units=imperial
# Processing Record 36 of Set 2 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=luderitz&units=imperial
# Processing Record 37 of Set 2 | andenes
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=andenes&units=imperial
# Processing Record 38 of Set 2 | jining
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=jining&units=imperial
# Processing Record 39 of Set 2 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=norman wells&units=imperial
# Processing Record 40 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=busselton&units=imperial
# Processing Record 41 of Set 2 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=dikson&units=imperial
# Processing Record 42 of Set 2 | hovd
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hovd&units=imperial
# Processing Record 43 of Set 2 | colombo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=colombo&units=imperial
# Processing Record 44 of Set 2 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=narsaq&units=imperial
# Processing Record 45 of Set 2 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=faanui&units=imperial
# Processing Record 46 of Set 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saskylakh&units=imperial
# Processing Record 47 of Set 2 | alpena
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=alpena&units=imperial
# Processing Record 48 of Set 2 | presidencia roque saenz pena
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=presidencia roque saenz pena&units=imperial
# City not found... Skipping sentyabrskiy
# Processing Record 49 of Set 2 | ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ahipara&units=imperial
# Processing Record 50 of Set 2 | miri
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=miri&units=imperial
# Processing Record 1 of Set 3 | lavumisa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lavumisa&units=imperial
# Processing Record 2 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=upernavik&units=imperial
# Processing Record 3 of Set 3 | visby
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=visby&units=imperial
# Processing Record 4 of Set 3 | husavik
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=husavik&units=imperial
# Processing Record 5 of Set 3 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=yar-sale&units=imperial
# Processing Record 6 of Set 3 | rye
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rye&units=imperial
# Processing Record 7 of Set 3 | laguna
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=laguna&units=imperial
# Processing Record 8 of Set 3 | toppenish
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=toppenish&units=imperial
# Processing Record 9 of Set 3 | invermere
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=invermere&units=imperial
# Processing Record 10 of Set 3 | porto novo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=porto novo&units=imperial
# Processing Record 11 of Set 3 | margate
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=margate&units=imperial
# Processing Record 12 of Set 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=longyearbyen&units=imperial
# Processing Record 13 of Set 3 | roald
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=roald&units=imperial
# Processing Record 14 of Set 3 | syamzha
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=syamzha&units=imperial
# Processing Record 15 of Set 3 | kondoa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kondoa&units=imperial
# Processing Record 16 of Set 3 | icod de los vinos
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=icod de los vinos&units=imperial
# Processing Record 17 of Set 3 | pochutla
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=pochutla&units=imperial
# Processing Record 18 of Set 3 | beyneu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=beyneu&units=imperial
# Processing Record 19 of Set 3 | parral
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=parral&units=imperial
# Processing Record 20 of Set 3 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint george&units=imperial
# Processing Record 21 of Set 3 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=iqaluit&units=imperial
# Processing Record 22 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=carnarvon&units=imperial
# Processing Record 23 of Set 3 | atri
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=atri&units=imperial
# Processing Record 24 of Set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ribeira grande&units=imperial
# Processing Record 25 of Set 3 | lesogorskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lesogorskiy&units=imperial
# City not found... Skipping buariki
# Processing Record 26 of Set 3 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tuatapere&units=imperial
# Processing Record 27 of Set 3 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sitka&units=imperial
# Processing Record 28 of Set 3 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bambous virieux&units=imperial
# Processing Record 29 of Set 3 | tarko-sale
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tarko-sale&units=imperial
# Processing Record 30 of Set 3 | rocha
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rocha&units=imperial
# Processing Record 31 of Set 3 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ilulissat&units=imperial
# Processing Record 32 of Set 3 | marrakesh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=marrakesh&units=imperial
# Processing Record 33 of Set 3 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=souillac&units=imperial
# Processing Record 34 of Set 3 | adrar
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=adrar&units=imperial
# Processing Record 35 of Set 3 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kaitangata&units=imperial
# Processing Record 36 of Set 3 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hermanus&units=imperial
# City not found... Skipping doctor pedro p. pena
# City not found... Skipping ambodifototra
# Processing Record 37 of Set 3 | jackson
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=jackson&units=imperial
# City not found... Skipping samusu
# Processing Record 38 of Set 3 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mar del plata&units=imperial
# City not found... Skipping belushya guba
# Processing Record 39 of Set 3 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=castro&units=imperial
# Processing Record 40 of Set 3 | rivera
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rivera&units=imperial
# Processing Record 41 of Set 3 | sebezh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sebezh&units=imperial
# Processing Record 42 of Set 3 | kattivakkam
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kattivakkam&units=imperial
# Processing Record 43 of Set 3 | beidao
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=beidao&units=imperial
# Processing Record 44 of Set 3 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bathsheba&units=imperial
# Processing Record 45 of Set 3 | chalchihuites
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=chalchihuites&units=imperial
# Processing Record 46 of Set 3 | aksu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=aksu&units=imperial
# Processing Record 47 of Set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hithadhoo&units=imperial
# Processing Record 48 of Set 3 | staryy saltiv
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=staryy saltiv&units=imperial
# Processing Record 49 of Set 3 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=geraldton&units=imperial
# Processing Record 50 of Set 3 | oer-erkenschwick
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=oer-erkenschwick&units=imperial
# Processing Record 1 of Set 4 | hami
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hami&units=imperial
# Processing Record 2 of Set 4 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=belyy yar&units=imperial
# Processing Record 3 of Set 4 | coos bay
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=coos bay&units=imperial
# Processing Record 4 of Set 4 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=berdigestyakh&units=imperial
# Processing Record 5 of Set 4 | kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kununurra&units=imperial
# Processing Record 6 of Set 4 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ketchikan&units=imperial
# Processing Record 7 of Set 4 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kavieng&units=imperial
# Processing Record 8 of Set 4 | buraydah
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=buraydah&units=imperial
# Processing Record 9 of Set 4 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=esperance&units=imperial
# Processing Record 10 of Set 4 | burns lake
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=burns lake&units=imperial
# Processing Record 11 of Set 4 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint-philippe&units=imperial
# Processing Record 12 of Set 4 | fergus falls
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=fergus falls&units=imperial
# Processing Record 13 of Set 4 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=meulaboh&units=imperial
# Processing Record 14 of Set 4 | urumqi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=urumqi&units=imperial
# Processing Record 15 of Set 4 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=east london&units=imperial
# Processing Record 16 of Set 4 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=klaksvik&units=imperial
# Processing Record 17 of Set 4 | arman
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=arman&units=imperial
# Processing Record 18 of Set 4 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=talnakh&units=imperial
# Processing Record 19 of Set 4 | quang ngai
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=quang ngai&units=imperial
# Processing Record 20 of Set 4 | khandbari
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=khandbari&units=imperial
# Processing Record 21 of Set 4 | samarai
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=samarai&units=imperial
# Processing Record 22 of Set 4 | ferkessedougou
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ferkessedougou&units=imperial
# Processing Record 23 of Set 4 | jaleswar
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=jaleswar&units=imperial
# Processing Record 24 of Set 4 | natal
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=natal&units=imperial
# Processing Record 25 of Set 4 | forbes
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=forbes&units=imperial
# Processing Record 26 of Set 4 | harper
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=harper&units=imperial
# Processing Record 27 of Set 4 | asyut
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=asyut&units=imperial
# Processing Record 28 of Set 4 | makaryev
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=makaryev&units=imperial
# Processing Record 29 of Set 4 | tocopilla
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tocopilla&units=imperial
# Processing Record 30 of Set 4 | road town
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=road town&units=imperial
# Processing Record 31 of Set 4 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=qaqortoq&units=imperial
# Processing Record 32 of Set 4 | ippy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ippy&units=imperial
# Processing Record 33 of Set 4 | longview
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=longview&units=imperial
# City not found... Skipping grand river south east
# Processing Record 34 of Set 4 | caluquembe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=caluquembe&units=imperial
# Processing Record 35 of Set 4 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=broome&units=imperial
# Processing Record 36 of Set 4 | champerico
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=champerico&units=imperial
# Processing Record 37 of Set 4 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ahuimanu&units=imperial
# Processing Record 38 of Set 4 | moron
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=moron&units=imperial
# Processing Record 39 of Set 4 | panama city
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=panama city&units=imperial
# Processing Record 40 of Set 4 | marabba
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=marabba&units=imperial
# Processing Record 41 of Set 4 | mecca
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mecca&units=imperial
# Processing Record 42 of Set 4 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=abu samrah&units=imperial
# Processing Record 43 of Set 4 | northam
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=northam&units=imperial
# Processing Record 44 of Set 4 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=raudeberg&units=imperial
# Processing Record 45 of Set 4 | jiwani
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=jiwani&units=imperial
# Processing Record 46 of Set 4 | te anau
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=te anau&units=imperial
# Processing Record 47 of Set 4 | faya
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=faya&units=imperial
# Processing Record 48 of Set 4 | sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sungaipenuh&units=imperial
# Processing Record 49 of Set 4 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=coquimbo&units=imperial
# Processing Record 50 of Set 4 | saint-louis
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint-louis&units=imperial
# City not found... Skipping suao
# Processing Record 1 of Set 5 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tiksi&units=imperial
# Processing Record 2 of Set 5 | tecpan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tecpan&units=imperial
# City not found... Skipping barentsburg
# Processing Record 3 of Set 5 | bonthe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bonthe&units=imperial
# Processing Record 4 of Set 5 | rexburg
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rexburg&units=imperial
# Processing Record 5 of Set 5 | kokopo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kokopo&units=imperial
# Processing Record 6 of Set 5 | kirakira
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kirakira&units=imperial
# Processing Record 7 of Set 5 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=katsuura&units=imperial
# Processing Record 8 of Set 5 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mount gambier&units=imperial
# Processing Record 9 of Set 5 | kribi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kribi&units=imperial
# City not found... Skipping mullaitivu
# Processing Record 10 of Set 5 | dabat
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=dabat&units=imperial
# Processing Record 11 of Set 5 | berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=berlevag&units=imperial
# Processing Record 12 of Set 5 | sarkand
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sarkand&units=imperial
# Processing Record 13 of Set 5 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=new norfolk&units=imperial
# Processing Record 14 of Set 5 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=solnechnyy&units=imperial
# Processing Record 15 of Set 5 | novo aripuana
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=novo aripuana&units=imperial
# Processing Record 16 of Set 5 | quthing
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=quthing&units=imperial
# Processing Record 17 of Set 5 | kalaleh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kalaleh&units=imperial
# Processing Record 18 of Set 5 | matara
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=matara&units=imperial
# Processing Record 19 of Set 5 | trat
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=trat&units=imperial
# Processing Record 20 of Set 5 | andros town
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=andros town&units=imperial
# Processing Record 21 of Set 5 | beloha
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=beloha&units=imperial
# Processing Record 22 of Set 5 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mahebourg&units=imperial
# Processing Record 23 of Set 5 | kuytun
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kuytun&units=imperial
# Processing Record 24 of Set 5 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=udachnyy&units=imperial
# Processing Record 25 of Set 5 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cabo san lucas&units=imperial
# Processing Record 26 of Set 5 | parainen
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=parainen&units=imperial
# Processing Record 27 of Set 5 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nanortalik&units=imperial
# Processing Record 28 of Set 5 | aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=aklavik&units=imperial
# Processing Record 29 of Set 5 | sinop
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sinop&units=imperial
# Processing Record 30 of Set 5 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port elizabeth&units=imperial
# Processing Record 31 of Set 5 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=los llanos de aridane&units=imperial
# Processing Record 32 of Set 5 | avanigadda
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=avanigadda&units=imperial
# Processing Record 33 of Set 5 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lebu&units=imperial
# Processing Record 34 of Set 5 | severnyy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=severnyy&units=imperial
# Processing Record 35 of Set 5 | namibe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=namibe&units=imperial
# City not found... Skipping mentok
# Processing Record 36 of Set 5 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=jamestown&units=imperial
# Processing Record 37 of Set 5 | gat
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=gat&units=imperial
# Processing Record 38 of Set 5 | maiduguri
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=maiduguri&units=imperial
# Processing Record 39 of Set 5 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=guerrero negro&units=imperial
# Processing Record 40 of Set 5 | san luis
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=san luis&units=imperial
# Processing Record 41 of Set 5 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=egvekinot&units=imperial
# Processing Record 42 of Set 5 | shache
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=shache&units=imperial
# Processing Record 43 of Set 5 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ostrovnoy&units=imperial
# Processing Record 44 of Set 5 | corpus christi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=corpus christi&units=imperial
# Processing Record 45 of Set 5 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=fort nelson&units=imperial
# Processing Record 46 of Set 5 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=thompson&units=imperial
# Processing Record 47 of Set 5 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kruisfontein&units=imperial
# Processing Record 48 of Set 5 | chebenki
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=chebenki&units=imperial
# Processing Record 49 of Set 5 | bondo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bondo&units=imperial
# Processing Record 50 of Set 5 | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=san patricio&units=imperial
# Processing Record 1 of Set 6 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hamilton&units=imperial
# Processing Record 2 of Set 6 | bonavista
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bonavista&units=imperial
# Processing Record 3 of Set 6 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint-georges&units=imperial
# Processing Record 4 of Set 6 | mount isa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mount isa&units=imperial
# Processing Record 5 of Set 6 | vangaindrano
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vangaindrano&units=imperial
# Processing Record 6 of Set 6 | verkhnyaya salda
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=verkhnyaya salda&units=imperial
# Processing Record 7 of Set 6 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ancud&units=imperial
# Processing Record 8 of Set 6 | vilhena
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vilhena&units=imperial
# Processing Record 9 of Set 6 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=arraial do cabo&units=imperial
# Processing Record 10 of Set 6 | hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hambantota&units=imperial
# Processing Record 11 of Set 6 | ankazobe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ankazobe&units=imperial
# Processing Record 12 of Set 6 | roros
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=roros&units=imperial
# Processing Record 13 of Set 6 | camacha
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=camacha&units=imperial
# City not found... Skipping umm durman
# Processing Record 14 of Set 6 | berbera
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=berbera&units=imperial
# Processing Record 15 of Set 6 | kropotkin
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kropotkin&units=imperial
# Processing Record 16 of Set 6 | haines junction
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=haines junction&units=imperial
# Processing Record 17 of Set 6 | garissa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=garissa&units=imperial
# Processing Record 18 of Set 6 | sovetskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sovetskiy&units=imperial
# Processing Record 19 of Set 6 | venice
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=venice&units=imperial
# City not found... Skipping bokspits
# Processing Record 20 of Set 6 | poway
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=poway&units=imperial
# Processing Record 21 of Set 6 | port augusta
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port augusta&units=imperial
# Processing Record 22 of Set 6 | san felipe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=san felipe&units=imperial
# Processing Record 23 of Set 6 | urucara
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=urucara&units=imperial
# Processing Record 24 of Set 6 | toba
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=toba&units=imperial
# Processing Record 25 of Set 6 | westport
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=westport&units=imperial
# Processing Record 26 of Set 6 | havoysund
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=havoysund&units=imperial
# Processing Record 27 of Set 6 | auki
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=auki&units=imperial
# Processing Record 28 of Set 6 | puerto suarez
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=puerto suarez&units=imperial
# Processing Record 29 of Set 6 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=fortuna&units=imperial
# Processing Record 30 of Set 6 | limbang
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=limbang&units=imperial
# Processing Record 31 of Set 6 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=zhigansk&units=imperial
# Processing Record 32 of Set 6 | mpika
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mpika&units=imperial
# Processing Record 33 of Set 6 | shubarkuduk
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=shubarkuduk&units=imperial
# Processing Record 34 of Set 6 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=comodoro rivadavia&units=imperial
# Processing Record 35 of Set 6 | monrovia
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=monrovia&units=imperial
# Processing Record 36 of Set 6 | arkansas city
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=arkansas city&units=imperial
# Processing Record 37 of Set 6 | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=flinders&units=imperial
# City not found... Skipping kuche
# Processing Record 38 of Set 6 | rundu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rundu&units=imperial
# Processing Record 39 of Set 6 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=grand gaube&units=imperial
# Processing Record 40 of Set 6 | pemba
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=pemba&units=imperial
# Processing Record 41 of Set 6 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saldanha&units=imperial
# Processing Record 42 of Set 6 | palencia
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=palencia&units=imperial
# Processing Record 43 of Set 6 | north bend
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=north bend&units=imperial
# Processing Record 44 of Set 6 | manavalakurichi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=manavalakurichi&units=imperial
# Processing Record 45 of Set 6 | hay river
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hay river&units=imperial
# Processing Record 46 of Set 6 | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=la ronge&units=imperial
# Processing Record 47 of Set 6 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=komsomolskiy&units=imperial
# Processing Record 48 of Set 6 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=isangel&units=imperial
# Processing Record 49 of Set 6 | grand-lahou
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=grand-lahou&units=imperial
# Processing Record 50 of Set 6 | bukama
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bukama&units=imperial
# Processing Record 1 of Set 7 | nara
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nara&units=imperial
# Processing Record 2 of Set 7 | itaberai
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=itaberai&units=imperial
# Processing Record 3 of Set 7 | acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=acapulco&units=imperial
# Processing Record 4 of Set 7 | butajira
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=butajira&units=imperial
# Processing Record 5 of Set 7 | nguruka
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nguruka&units=imperial
# Processing Record 6 of Set 7 | chuy
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=villa maria&units=imperial
# Processing Record 26 of Set 10 | tricase
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tricase&units=imperial
# Processing Record 27 of Set 10 | byron bay
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=byron bay&units=imperial
# Processing Record 28 of Set 10 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cayenne&units=imperial
# Processing Record 29 of Set 10 | mugur-aksy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mugur-aksy&units=imperial
# Processing Record 30 of Set 10 | borgarnes
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=borgarnes&units=imperial
# Processing Record 31 of Set 10 | sagaing
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sagaing&units=imperial
# Processing Record 32 of Set 10 | alto araguaia
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=alto araguaia&units=imperial
# Processing Record 33 of Set 10 | asau
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=asau&units=imperial
# Processing Record 34 of Set 10 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=maniitsoq&units=imperial
# Processing Record 35 of Set 10 | dashitou
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=dashitou&units=imperial
# Processing Record 36 of Set 10 | ostersund
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ostersund&units=imperial
# Processing Record 37 of Set 10 | naryan-mar
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=naryan-mar&units=imperial
# Processing Record 38 of Set 10 | monroe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=monroe&units=imperial
# Processing Record 39 of Set 10 | sherbakul
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sherbakul&units=imperial
# Processing Record 40 of Set 10 | hauterive
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hauterive&units=imperial
# Processing Record 41 of Set 10 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=yerbogachen&units=imperial
# City not found... Skipping kamenskoye
# Processing Record 42 of Set 10 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tazovskiy&units=imperial
# Processing Record 43 of Set 10 | mae hong son
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mae hong son&units=imperial
# Processing Record 44 of Set 10 | kuyanovo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kuyanovo&units=imperial
# Processing Record 45 of Set 10 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port lincoln&units=imperial
# Processing Record 46 of Set 10 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=batemans bay&units=imperial
# Processing Record 47 of Set 10 | burnie
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=burnie&units=imperial
# Processing Record 48 of Set 10 | binga
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=binga&units=imperial
# Processing Record 49 of Set 10 | zaysan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=zaysan&units=imperial
# Processing Record 50 of Set 10 | kenitra
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kenitra&units=imperial
# Processing Record 1 of Set 11 | ardahan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ardahan&units=imperial
# Processing Record 2 of Set 11 | sironko
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sironko&units=imperial
# Processing Record 3 of Set 11 | kindu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kindu&units=imperial
# Processing Record 4 of Set 11 | elko
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=elko&units=imperial
# City not found... Skipping lolua
# Processing Record 5 of Set 11 | tezu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tezu&units=imperial
# City not found... Skipping vaitupu
# Processing Record 6 of Set 11 | waipawa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=waipawa&units=imperial
# Processing Record 7 of Set 11 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=pitimbu&units=imperial
# Processing Record 8 of Set 11 | tikapur
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tikapur&units=imperial
# Processing Record 9 of Set 11 | standerton
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=standerton&units=imperial
# Processing Record 10 of Set 11 | durban
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=durban&units=imperial
# Processing Record 11 of Set 11 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sao filipe&units=imperial
# Processing Record 12 of Set 11 | korla
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=korla&units=imperial
# Processing Record 13 of Set 11 | biak
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=biak&units=imperial
# Processing Record 14 of Set 11 | merauke
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=merauke&units=imperial
# Processing Record 15 of Set 11 | mgachi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mgachi&units=imperial
# Processing Record 16 of Set 11 | nahavand
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nahavand&units=imperial
# Processing Record 17 of Set 11 | pangody
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=pangody&units=imperial
# Processing Record 18 of Set 11 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lagoa&units=imperial
# Processing Record 19 of Set 11 | huilong
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=huilong&units=imperial
# Processing Record 20 of Set 11 | kainantu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kainantu&units=imperial
# Processing Record 21 of Set 11 | hailar
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hailar&units=imperial
# Processing Record 22 of Set 11 | teya
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=teya&units=imperial
# City not found... Skipping bargal
# Processing Record 23 of Set 11 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=olafsvik&units=imperial
# Processing Record 24 of Set 11 | muyezerskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=muyezerskiy&units=imperial
# City not found... Skipping hihifo
# Processing Record 25 of Set 11 | seymchan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=seymchan&units=imperial
# Processing Record 26 of Set 11 | omboue
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=omboue&units=imperial
# Processing Record 27 of Set 11 | tukrah
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tukrah&units=imperial
# Processing Record 28 of Set 11 | taonan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=taonan&units=imperial
# Processing Record 29 of Set 11 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=puerto escondido&units=imperial
# Processing Record 30 of Set 11 | port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port hardy&units=imperial
# Processing Record 31 of Set 11 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sobolevo&units=imperial
# Processing Record 32 of Set 11 | namatanai
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=namatanai&units=imperial
# Processing Record 33 of Set 11 | kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kurilsk&units=imperial
# Processing Record 34 of Set 11 | fort frances
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=fort frances&units=imperial
# Processing Record 35 of Set 11 | lluta
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lluta&units=imperial
# City not found... Skipping sofiysk
# Processing Record 36 of Set 11 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vardo&units=imperial
# Processing Record 37 of Set 11 | pizarro
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=pizarro&units=imperial
# Processing Record 38 of Set 11 | parsons
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=parsons&units=imperial
# Processing Record 39 of Set 11 | aitape
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=aitape&units=imperial
# Processing Record 40 of Set 11 | ningxiang
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ningxiang&units=imperial
# Processing Record 41 of Set 11 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=valparaiso&units=imperial
# Processing Record 42 of Set 11 | yaan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=yaan&units=imperial
# Processing Record 43 of Set 11 | pierre
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=pierre&units=imperial
# Processing Record 44 of Set 11 | new bern
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=new bern&units=imperial
# Processing Record 45 of Set 11 | amarwara
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=amarwara&units=imperial
# Processing Record 46 of Set 11 | nishihara
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nishihara&units=imperial
# Processing Record 47 of Set 11 | nagua
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nagua&units=imperial
# Processing Record 48 of Set 11 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rio gallegos&units=imperial
# Processing Record 49 of Set 11 | galesong
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=galesong&units=imperial
# Processing Record 50 of Set 11 | choix
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=choix&units=imperial
# City not found... Skipping sorvag
# Processing Record 1 of Set 12 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tilichiki&units=imperial
# Processing Record 2 of Set 12 | gigmoto
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=gigmoto&units=imperial
# Processing Record 3 of Set 12 | bacolod
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bacolod&units=imperial
# Processing Record 4 of Set 12 | kilgore
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kilgore&units=imperial
# Processing Record 5 of Set 12 | tatarskaya kargala
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tatarskaya kargala&units=imperial
# Processing Record 6 of Set 12 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kodiak&units=imperial
# Processing Record 7 of Set 12 | puerto ayacucho
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=puerto ayacucho&units=imperial
# Processing Record 8 of Set 12 | bull savanna
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bull savanna&units=imperial
# City not found... Skipping pilao arcado
# Processing Record 9 of Set 12 | matadi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=matadi&units=imperial
# Processing Record 10 of Set 12 | san jose de gracia
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=san jose de gracia&units=imperial
# City not found... Skipping toliary
# Processing Record 11 of Set 12 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=skjervoy&units=imperial
# Processing Record 12 of Set 12 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sur&units=imperial
# Processing Record 13 of Set 12 | katherine
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=katherine&units=imperial
# Processing Record 14 of Set 12 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port-gentil&units=imperial
# Processing Record 15 of Set 12 | hohhot
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hohhot&units=imperial
# Processing Record 16 of Set 12 | nenagh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nenagh&units=imperial
# Processing Record 17 of Set 12 | christchurch
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=christchurch&units=imperial
# City not found... Skipping palkaka
# Processing Record 18 of Set 12 | sandy bay
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sandy bay&units=imperial
# Processing Record 19 of Set 12 | havelock
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=havelock&units=imperial
# Processing Record 20 of Set 12 | ipil
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ipil&units=imperial
# Processing Record 21 of Set 12 | mishan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mishan&units=imperial
# Processing Record 22 of Set 12 | longonjo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=longonjo&units=imperial
# Processing Record 23 of Set 12 | itarema
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=itarema&units=imperial
# Processing Record 24 of Set 12 | ndele
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ndele&units=imperial
# Processing Record 25 of Set 12 | grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=grindavik&units=imperial
# Processing Record 26 of Set 12 | bueno brandao
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bueno brandao&units=imperial

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create city data frame
city_df = pd.DataFrame({"City" : city,
                       "Cloudiness" : cloudiness,
                       "Country" : country,
                       "Date" : date,
                       "Humidity" : humidity,
                       "Lat" : lat,
                       "Lng" : lng,
                       "Max Temp" : max_temp,
                       "Wind Speed" : wind_speed})

city_df.count()
# Out:
# City          576
# Cloudiness    576
# Country       576
# Date          576
# Humidity      576
# Lat           576
# Lng           576
# Max Temp      576
# Wind Speed    576
# dtype: int64

# %%
#export to csv file
output_file = os.path.join(output_dir[0], output_dir[1])
city_df.to_csv(output_file, index=True)

# %%
city_df
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    San Cristobal          40      VE  1604609349        58   7.77  -72.22
# 1           Avarua          81      CK  1604609591        83 -21.21 -159.78
# 2              Vao           0      NC  1604609591        83 -22.67  167.48
# 3           Albany          75      US  1604609488        45  42.60  -73.97
# 4       Butaritari          32      KI  1604609591        78   3.07  172.79
# ..             ...         ...     ...         ...       ...    ...     ...
# 571       Longonjo          99      AO  1604610248        81 -12.91   15.25
# 572        Itarema           0      BR  1604610254        75  -2.92  -39.92
# 573          Ndélé         100      CF  1604610254        49   8.41   20.65
# 574      Grindavik          75      IS  1604609975        75  63.84  -22.43
# 575  Bueno Brandão          30      BR  1604610254        78 -22.44  -46.35
#
#      Max Temp  Wind Speed
# 0       87.80       12.75
# 1       73.40       13.87
# 2       74.62        9.40
# 3       66.20       11.41
# 4       81.79        8.90
# ..        ...         ...
# 571     65.97        1.97
# 572     80.28       15.01
# 573     75.72        0.60
# 574     41.00       40.26
# 575     61.83        3.24
#
# [576 rows x 9 columns]

# %%
city_df.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  576.000000  5.760000e+02  576.000000  576.000000  576.000000
# mean    49.720486  1.604610e+09   70.347222   20.418872   15.259062
# std     39.773008  2.231107e+02   21.666185   32.825680   88.045252
# min      0.000000  1.604609e+09   11.000000  -54.800000 -179.170000
# 25%      2.000000  1.604610e+09   57.000000   -5.797500  -64.740000
# 50%     46.000000  1.604610e+09   76.000000   25.035000   24.120000
# 75%     90.000000  1.604610e+09   87.000000   47.117500   87.300000
# max    100.000000  1.604610e+09  100.000000   78.220000  178.420000
#
#          Max Temp  Wind Speed
# count  576.000000  576.000000
# mean    59.500278    8.285451
# std     22.591429    6.366329
# min     -8.880000    0.220000
# 25%     46.400000    3.937500
# 50%     65.860000    6.930000
# 75%     77.000000   11.410000
# max    104.290000   51.270000

# %% [markdown]
# **Remove cities where Humidity > 100%**
# Not necessary if there are no cities with Humidity > 100%

# %%
humid_cities = city_df["City"].loc[city_df["Humidity"] > 100].count()
if humid_cities > 0:
    city_df = city_df.loc[city_df["Humidity"] <= 100]
city_df
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    San Cristobal          40      VE  1604609349        58   7.77  -72.22
# 1           Avarua          81      CK  1604609591        83 -21.21 -159.78
# 2              Vao           0      NC  1604609591        83 -22.67  167.48
# 3           Albany          75      US  1604609488        45  42.60  -73.97
# 4       Butaritari          32      KI  1604609591        78   3.07  172.79
# ..             ...         ...     ...         ...       ...    ...     ...
# 571       Longonjo          99      AO  1604610248        81 -12.91   15.25
# 572        Itarema           0      BR  1604610254        75  -2.92  -39.92
# 573          Ndélé         100      CF  1604610254        49   8.41   20.65
# 574      Grindavik          75      IS  1604609975        75  63.84  -22.43
# 575  Bueno Brandão          30      BR  1604610254        78 -22.44  -46.35
#
#      Max Temp  Wind Speed
# 0       87.80       12.75
# 1       73.40       13.87
# 2       74.62        9.40
# 3       66.20       11.41
# 4       81.79        8.90
# ..        ...         ...
# 571     65.97        1.97
# 572     80.28       15.01
# 573     75.72        0.60
# 574     41.00       40.26
# 575     61.83        3.24
#
# [576 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# create a scatter plot latitude v temperature
from datetime import datetime
dt = int(date[0])
plot_date = datetime.fromtimestamp(dt).strftime('%y/%m/%d')
x_lat = city_df['Lat']
y_temp = city_df['Max Temp']
fig, ax = plt.subplots(figsize=(7,7))
ax.set_autoscale_on(True)
ax.scatter(x_lat, y_temp)
plt.title(f"City Latitude vs Max Temperature ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_temp.png")
plt.savefig(file)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
y_hum = city_df["Humidity"]

fig, ax1 = plt.subplots(figsize=(7,7))
ax1.set_autoscale_on(True)
ax1.scatter(x_lat, y_hum)
plt.title(f"City Latitude vs Humidity ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_humid.png")
plt.savefig(file)

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
y_cloud = city_df["Cloudiness"]
fig, ax2 = plt.subplots(figsize=(7,7))
ax2.set_autoscale_on(True)
ax2.scatter(x_lat, y_cloud)
plt.title(f"City Latitude vs Cloudiness ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_cloud.png")
plt.savefig(file)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
y_wind = city_df["Wind Speed"]
fig, ax3 = plt.subplots(figsize=(7,7))
ax3.set_autoscale_on(True)
ax3.scatter(x_lat, y_wind)
plt.title(f"City Latitude vs Wind Speed ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_wind.png")
plt.savefig(file)

# %% [markdown]
# ## Linear Regression

# %%
# dependencies
import scipy.stats as st

# %% [markdown]
# ### Create data frame for northern and southern hemispheres

# %%
# northern hemisphere data frame
north_df = city_df[city_df["Lat"] >= 0]
north_df
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    San Cristobal          40      VE  1604609349        58   7.77  -72.22
# 3           Albany          75      US  1604609488        45  42.60  -73.97
# 4       Butaritari          32      KI  1604609591        78   3.07  172.79
# 5         Khatanga         100      RU  1604609592        90  71.97  102.50
# 6       Winnemucca           1      US  1604609297        12  40.97 -117.74
# ..             ...         ...     ...         ...       ...    ...     ...
# 568       Havelock           5      US  1604610230        56  34.88  -76.90
# 569           Ipil         100      PH  1604610253        89   7.75  122.52
# 570         Mishan          16      CN  1604610254        96  45.55  131.88
# 573          Ndélé         100      CF  1604610254        49   8.41   20.65
# 574      Grindavik          75      IS  1604609975        75  63.84  -22.43
#
#      Max Temp  Wind Speed
# 0       87.80       12.75
# 3       66.20       11.41
# 4       81.79        8.90
# 5       -4.61        1.79
# 6       71.60        3.36
# ..        ...         ...
# 568     73.99       11.41
# 569     75.61        4.14
# 570     31.48        4.12
# 573     75.72        0.60
# 574     41.00       40.26
#
# [403 rows x 9 columns]

# %%
# southern hemisphere data frame
south_df = city_df[city_df["Lat"] < 0]
south_df
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 1           Avarua          81      CK  1604609591        83 -21.21 -159.78
# 2              Vao           0      NC  1604609591        83 -22.67  167.48
# 10      Bredasdorp         100      ZA  1604609592        82 -34.53   20.04
# 16    Punta Arenas          75      CL  1604609593        30 -53.15  -70.92
# 17         Rikitea          39      PF  1604609593        68 -23.12 -134.97
# ..             ...         ...     ...         ...       ...    ...     ...
# 566   Christchurch         100      NZ  1604610178        93 -43.53  172.63
# 567      Sandy Bay          75      AU  1604610253        58 -42.91  147.35
# 571       Longonjo          99      AO  1604610248        81 -12.91   15.25
# 572        Itarema           0      BR  1604610254        75  -2.92  -39.92
# 575  Bueno Brandão          30      BR  1604610254        78 -22.44  -46.35
#
#      Max Temp  Wind Speed
# 1       73.40       13.87
# 2       74.62        9.40
# 10      66.20       12.75
# 16      55.40       20.80
# 17      74.35       12.08
# ..        ...         ...
# 566     57.00       13.87
# 567     54.00       14.99
# 571     65.97        1.97
# 572     80.28       15.01
# 575     61.83        3.24
#
# [173 rows x 9 columns]

# %% [markdown]
# ### Northern Hemisphere - Max Temperature vs Latitude

# %%
north_x_lat = north_df["Lat"]
north_y_temp = north_df["Max Temp"]

nt_corr_coef = round(st.pearsonr(north_x_lat, north_y_temp)[0],2)
print(f"correlation coefficient: {nt_corr_coef}")

n_temp = st.linregress(north_x_lat, north_y_temp)
print(f"The r-value is {round(n_temp.rvalue,2)}")
# Out:
# correlation coefficient: -0.83
# The r-value is -0.83

# %%
#create equation of line
line = n_temp.slope * north_x_lat + n_temp.intercept
line_eq = f"y = {round(n_temp.slope,2)}x + {round(n_temp.intercept,2)}"

# plot linear model on top of scatter plot
fig, ax = plt.subplots(figsize=(7,7))
ax.set_autoscale_on(True)
ax.scatter(north_x_lat, north_y_temp, marker='.', facecolors="blue", edgecolors="blue")
plt.plot(north_x_lat, line, 'r-')
plt.title(f"Northern Hemisphere - Max Temp vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.annotate(line_eq, (0,0), fontsize=12, color="red")

file = os.path.join("images", "north_lat_temp.png")
plt.savefig(file)

# %% [markdown]
# ### Southern Hemisphere - Max Temperature vs Latitude

# %%
south_x_lat = south_df["Lat"]
south_y_temp = south_df["Max Temp"]

s_corr_coef = round(st.pearsonr(south_x_lat, south_y_temp)[0],2)
print(f"correlation coefficient: {s_corr_coef}")

s_temp = st.linregress(south_x_lat, south_y_temp)
print(f"The r-value is {s_temp.rvalue}")
# Out:
# correlation coefficient: 0.68
# The r-value is 0.6815327590508988

# %%
#create equation of line
line = s_temp.slope * south_x_lat + s_temp.intercept
line_eq = f"y = {round(s_temp.slope,2)}x + {round(s_temp.intercept,2)}"

# plot linear model on top of scatter plot
fig, axs = plt.subplots(figsize=(7,7))
axs.set_autoscale_on(True)
axs.scatter(south_x_lat, south_y_temp, marker='.', facecolors="blue", edgecolors="blue")
plt.plot(south_x_lat, line, 'r-')
plt.title(f"Southern Hemisphere - Max Temp vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.annotate(line_eq, (-50,80), fontsize=12, color="red")

file = os.path.join("images", "south_lat_temp.png")
plt.savefig(file)

# %% [markdown]
# **Temperature (F) vs Latitude Linear Regression (Northern and Southern Hemisphere)**
#
# * The correlation coeffient and linear regression model shows a strong negative correlation between latitude and maximum temperature in the northern hemisphere. As the latitude decreases, the temperature increases.
#
# * In the southern hemisphere, the correlation coefficient and linear regression model shows a moderate positive correlation between latitude and maximum temperature. As the latitude increases towards zero, the temperature increases as well.

# %% [markdown]
# ### Northern Hemisphere - Humidity (%) vs Latitude

# %%
north_y_hum = north_df["Humidity"]

n_corr_coef = round(st.pearsonr(north_x_lat, north_y_hum)[0],2)
print(f"correlation coefficient: {n_corr_coef}")

n_humid = st.linregress(north_x_lat, north_y_hum)
print(f"The r-value is {n_humid.rvalue}")
# Out:
# correlation coefficient: 0.18
# The r-value is 0.18298152125151387

# %%
#create equation of line
line = n_humid.slope * north_x_lat + n_humid.intercept
line_eq = f"y = {round(n_humid.slope,2)}x + {round(n_humid.intercept,2)}"

# plot linear model on top of scatter plot
fig, nh = plt.subplots(figsize=(7,7))
nh.set_autoscale_on(True)
nh.scatter(north_x_lat, north_y_hum, marker='.', facecolors="green", edgecolors="green")
plt.plot(north_x_lat, line, 'b-')
plt.title(f"Northern Hemisphere - Humidity (%) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.annotate(line_eq, (50,20), fontsize=12, color="blue")

file = os.path.join("images", "north_lat_humid.png")
plt.savefig(file)

# %% [markdown]
# ### Southern Hemisphere - Humidity (%) vs Latitude

# %%
south_y_hum = south_df["Humidity"]

s_corr_coef = round(st.pearsonr(south_x_lat, south_y_hum)[0],2)
print(f"correlation coefficient: {s_corr_coef}")

s_humid = st.linregress(south_x_lat, south_y_hum)
print(f"The r-value is {s_humid.rvalue}")
# Out:
# correlation coefficient: 0.17
# The r-value is 0.17106282293916597

# %%
#create equation of line
line = s_humid.slope * south_x_lat + s_humid.intercept
line_eq = f"y = {round(s_humid.slope,2)}x + {round(s_humid.intercept,2)}"

# plot linear model on top of scatter plot
fig, sh = plt.subplots(figsize=(7,7))
sh.set_autoscale_on(True)
sh.scatter(south_x_lat, south_y_hum, marker='.', facecolors="green", edgecolors="green")
plt.plot(south_x_lat, line, 'b-')
plt.title(f"Southern Hemisphere - Humidity (%) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.annotate(line_eq, (-50,10), fontsize=12, color="blue")

file = os.path.join("images", "south_lat_humid.png")
plt.savefig(file)

# %% [markdown]
# **Humidity (%) vs Latitude Linear Regression (Northern and Southern Hemisphere)**
#
# * The correlation coefficent and linear regression model for humidity vs latitude shows a fairly positive correlation for both hemispheres.

# %% [markdown]
# ### Northern Hemisphere - Cloudiness (%) vs Latitude

# %%
north_y_cloud = north_df["Cloudiness"]

n_corr_coef = round(st.pearsonr(north_x_lat, north_y_cloud)[0],2)
print(f"correlation coefficient: {n_corr_coef}")

north_cloud = st.linregress(north_x_lat, north_y_cloud)
print(f"The r-value is {north_cloud.rvalue}")
# Out:
# correlation coefficient: 0.24
# The r-value is 0.24161214392949237

# %%
#create equation of line
line = north_cloud.slope * north_x_lat + north_cloud.intercept
line_eq = f"y = {round(north_cloud.slope,2)}x + {round(north_cloud.intercept,2)}"

# plot linear model on top of scatter plot
fig, nc = plt.subplots(figsize=(7,7))
nc.set_autoscale_on(True)
nc.scatter(north_x_lat, north_y_cloud, marker='o', facecolors="green", edgecolors="green")
plt.plot(north_x_lat, line, 'b-')
plt.title(f"Northern Hemisphere - Cloudiness (%) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.annotate(line_eq, (0, 60), fontsize=12, color="blue")

file = os.path.join("images", "north_lat_cloud.png")
plt.savefig(file)

# %% [markdown]
# ### Southern Hemisphere - Cloudiness (%) vs Latitude

# %%
south_y_cloud = south_df["Cloudiness"]

s_corr_coef = round(st.pearsonr(south_x_lat, south_y_cloud)[0],2)
print(f"correlation coefficient: {s_corr_coef}")

south_cloud = st.linregress(south_x_lat, south_y_cloud)
print(f"The r-value is {south_cloud.rvalue}")
# Out:
# correlation coefficient: 0.1
# The r-value is 0.1004986469783198

# %%
#create equation of line
line = south_cloud.slope * south_x_lat + south_cloud.intercept
line_eq = f"y = {round(south_cloud.slope,2)}x + {round(south_cloud.intercept,2)}"

# plot linear model on top of scatter plot
fig, sc = plt.subplots(figsize=(7,7))
sc.set_autoscale_on(True)
sc.scatter(south_x_lat, south_y_cloud, marker='o', facecolors="green", edgecolors="green")
plt.plot(south_x_lat, line, 'b-')
plt.title(f"Southern Hemisphere - Cloudiness (%) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.annotate(line_eq, (-55, 60), fontsize=12, color="blue")

file = os.path.join("images", "south_lat_cloud.png")
plt.savefig(file)

# %% [markdown]
# **Cloudiness (%) vs Latitude Linear Regression (Northern and Southern Hemisphere)**
#
# * The correlation coefficient and linear regression model show a weak positive correlation between cloudiness and latitude in the northern hemisphere and an even weaker positive correlation in the southern hemisphere.

# %% [markdown]
# ### Northern Hemisphere - Wind Speed (mph) vs Latitude

# %%
north_y_wind = north_df["Wind Speed"]

n_corr_coef = round(st.pearsonr(north_x_lat, north_y_wind)[0],2)
print(f"correlation coefficient: {n_corr_coef}")

north_wind = st.linregress(north_x_lat, north_y_wind)
print(f"The r-value is {north_wind.rvalue}")
# Out:
# correlation coefficient: 0.35
# The r-value is 0.3537847488209283

# %%
#create equation of line
line = north_wind.slope * north_x_lat + north_wind.intercept
line_eq = f"y = {round(north_wind.slope,2)}x + {round(north_wind.intercept,2)}"

# plot linear model on top of scatter plot
fig, nw = plt.subplots(figsize=(7,7))
nw.set_autoscale_on(True)
nw.scatter(north_x_lat, north_y_wind, marker='*', facecolors="green", edgecolors="green")
plt.plot(north_x_lat, line, 'b-')
plt.title(f"Northern Hemisphere - Wind Speed (mph) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.annotate(line_eq, (0, 50), fontsize=12, color="blue")

file = os.path.join("images", "north_lat_wind.png")
plt.savefig(file)

# %% [markdown]
# ### Southern Hemisphere - Wind Speed (mph) vs Latitude

# %%
south_y_wind = south_df["Wind Speed"]

s_corr_coef = round(st.pearsonr(south_x_lat, south_y_wind)[0],2)
print(f"correlation coefficient: {s_corr_coef}")

south_wind = st.linregress(south_x_lat, south_y_wind)
print(f"The r-value is {south_wind.rvalue}")
# Out:
# correlation coefficient: -0.31
# The r-value is -0.31254569660128045

# %%
#create equation of line
line = south_wind.slope * south_x_lat + south_wind.intercept
line_eq = f"y = {round(south_wind.slope,2)}x + {round(south_wind.intercept,2)}"

# plot linear model on top of scatter plot
fig, sw = plt.subplots(figsize=(7,7))
sw.set_autoscale_on(True)
sw.scatter(south_x_lat, south_y_wind, marker='*', facecolors="green", edgecolors="green")
plt.plot(south_x_lat, line, 'b-')
plt.title(f"Southern Hemisphere - Wind Speed (mph) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.annotate(line_eq, (-55, 3), fontsize=12, color="blue")

file = os.path.join("images", "south_lat_wind.png")
plt.savefig(file)

# %% [markdown]
# **Wind Speed (mph) vs Latitude Linear Regression (Northern and Southern Hemisphere)**
#
# * The correlation coefficient and linear regression model show a weak positive correlation between wind speed (mph) and latitude in the northern hemisphere.
#
# * The correlation coefficient and linear regression model show an almost moderate negative correlation between wind speed (mph) and latitude in the southern hemisphere.

# %% [markdown]
# ### Heat Map

# %%
colors = y_temp

fig, ax = plt.subplots(figsize=(10,8))
ax.set_autoscale_on(True)
plt.scatter(x_lat,y_temp, c=colors)
colorbar = plt.colorbar()
colorbar.ax.set_ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title("Temperature (F) vs Latitude")
plt.grid()

file = os.path.join("images", "heatmap.png")
plt.savefig(file)
