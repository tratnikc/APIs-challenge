# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
output_dir = output_data_file.split('/')

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = [] #?? get country code from citipy? 

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create url
units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={api_keys.api_key}&q={city}&units={units}"

# %%
# loop thru all cities, check if city can be found in openweathermap
# if found, add city to bucket set; if not found, skip and continue
# OpenWeatherMap free account allows 60 calls/min, 
# request 50 cities at a time, wait 55secs then continue loop

city = []       #response["name"]
cloudiness = [] #response["clouds"]["all"]
country = []    #response["sys"]["country"]
date = []       #response["dt"]
humidity = []   #response["main"]["humidity"]
lat = []        #response["coord"]["lat"]
lng = []        #response["coord"]["lon"]
max_temp = []   #response["main"]["temp_max"]
wind_speed = [] #response["wind"]["speed"]
city_not_found = []
sleep_interval = 0

basket_counter = 1
city_counter = 0

newline = '\n'
first_line = "Beginning Data Retrieval"
last_line = "Data Retrieval Complete"
just_line = "-------------------------------------"
not_found = "City not found... Skipping"
print(first_line)
print(just_line)
output_log = os.path.join(output_dir[0], "output_log.txt")
with open(output_log, 'w', newline='') as logfile:
    logfile.write(first_line + newline)
    logfile.write(just_line + newline)
    
    start_time = time.time()
    
    for x in range(len(cities)):

        query_url = f"{url}appid={api_keys.api_key}&q={cities[x]}&units={units}"
        
        response = requests.get(query_url).json()

        try:
            city.append(response["name"])

            try:
                country.append(response["sys"]["country"])
                date.append(response["dt"])
                humidity.append(response["main"]["humidity"])
                lat.append(response["coord"]["lat"])
                lng.append(response["coord"]["lon"])
                max_temp.append(response["main"]["temp_max"])
                wind_speed.append(response["wind"]["speed"])
                cloudiness.append(response["clouds"]["all"])

                city_counter += 1
                process_msg = f"Processing Record {city_counter} of Set {basket_counter} | {cities[x]}"
                print(process_msg)
                print(query_url)
                logfile.write(process_msg + newline)
                logfile.write(query_url + newline)
                
                if (len(city) % 50) == 0:
                    sleep_interval = time.time() - start_time
                    basket_counter += 1
                    city_counter = 0
                    time.sleep(60 - sleep_interval)
                    start_time = time.time()

            except:
                process_msg = "Other error."
                print(process_msg)
                logfile.write(process_msg + newline)
                pass

        except:
            process_msg = f"{not_found} {cities[x]}"
            print(process_msg)
            logfile.write(process_msg + newline)
            city_not_found.append(cities[x])
            pass

    logfile.write(just_line + newline)
    logfile.write(last_line + newline)
    logfile.write(just_line + newline)
# Out:
# Beginning Data Retrieval
# -------------------------------------
# Processing Record 1 of Set 1 | gorom-gorom
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=gorom-gorom&units=imperial
# Processing Record 2 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=avarua&units=imperial
# Processing Record 3 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mataura&units=imperial
# Processing Record 4 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mahebourg&units=imperial
# Processing Record 5 of Set 1 | sorong
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sorong&units=imperial
# Processing Record 6 of Set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tuatapere&units=imperial
# Processing Record 7 of Set 1 | araouane
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=araouane&units=imperial
# Processing Record 8 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=thompson&units=imperial
# City not found... Skipping marcona
# City not found... Skipping halalo
# Processing Record 9 of Set 1 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cayenne&units=imperial
# Processing Record 10 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hobart&units=imperial
# Processing Record 11 of Set 1 | pilar
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=pilar&units=imperial
# Processing Record 12 of Set 1 | ziniare
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ziniare&units=imperial
# Processing Record 13 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=jamestown&units=imperial
# Processing Record 14 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port alfred&units=imperial
# City not found... Skipping illoqqortoormiut
# Processing Record 15 of Set 1 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint anthony&units=imperial
# Processing Record 16 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cape town&units=imperial
# Processing Record 17 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=yellowknife&units=imperial
# Processing Record 18 of Set 1 | apache junction
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=apache junction&units=imperial
# Processing Record 19 of Set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vila franca do campo&units=imperial
# Processing Record 20 of Set 1 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ancud&units=imperial
# Processing Record 21 of Set 1 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=shenjiamen&units=imperial
# Processing Record 22 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vaini&units=imperial
# City not found... Skipping nizhneyansk
# Processing Record 23 of Set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bambous virieux&units=imperial
# Processing Record 24 of Set 1 | husavik
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=husavik&units=imperial
# Processing Record 25 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=new norfolk&units=imperial
# Processing Record 26 of Set 1 | rawson
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rawson&units=imperial
# Processing Record 27 of Set 1 | villaviciosa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=villaviciosa&units=imperial
# Processing Record 28 of Set 1 | soyo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=soyo&units=imperial
# Processing Record 29 of Set 1 | asau
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=asau&units=imperial
# Processing Record 30 of Set 1 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=victoria&units=imperial
# City not found... Skipping attawapiskat
# Processing Record 31 of Set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nanortalik&units=imperial
# Processing Record 32 of Set 1 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bathsheba&units=imperial
# Processing Record 33 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tuktoyaktuk&units=imperial
# Processing Record 34 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ribeira grande&units=imperial
# Processing Record 35 of Set 1 | xinpu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=xinpu&units=imperial
# Processing Record 36 of Set 1 | chulumani
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=chulumani&units=imperial
# Processing Record 37 of Set 1 | palmer
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=palmer&units=imperial
# Processing Record 38 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hilo&units=imperial
# Processing Record 39 of Set 1 | calbiga
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=calbiga&units=imperial
# Processing Record 40 of Set 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bengkulu&units=imperial
# Processing Record 41 of Set 1 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=broome&units=imperial
# Processing Record 42 of Set 1 | adrar
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=adrar&units=imperial
# Processing Record 43 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nikolskoye&units=imperial
# Processing Record 44 of Set 1 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sioux lookout&units=imperial
# Processing Record 45 of Set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=upernavik&units=imperial
# Processing Record 46 of Set 1 | french harbor
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=french harbor&units=imperial
# Processing Record 47 of Set 1 | kenai
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kenai&units=imperial
# Processing Record 48 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=albany&units=imperial
# Processing Record 49 of Set 1 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cabo san lucas&units=imperial
# Processing Record 50 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=puerto ayora&units=imperial
# Processing Record 1 of Set 2 | paliyad
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=paliyad&units=imperial
# Processing Record 2 of Set 2 | eureka
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=eureka&units=imperial
# Processing Record 3 of Set 2 | tangjiazhuang
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tangjiazhuang&units=imperial
# Processing Record 4 of Set 2 | santa maria
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=santa maria&units=imperial
# Processing Record 5 of Set 2 | novyy urengoy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=novyy urengoy&units=imperial
# City not found... Skipping samusu
# Processing Record 6 of Set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bluff&units=imperial
# Processing Record 7 of Set 2 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=abu samrah&units=imperial
# Processing Record 8 of Set 2 | nishihara
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nishihara&units=imperial
# Processing Record 9 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hermanus&units=imperial
# City not found... Skipping barentsburg
# Processing Record 10 of Set 2 | bulawayo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bulawayo&units=imperial
# Processing Record 11 of Set 2 | northam
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=northam&units=imperial
# Processing Record 12 of Set 2 | zhuhai
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=zhuhai&units=imperial
# Processing Record 13 of Set 2 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sitka&units=imperial
# Processing Record 14 of Set 2 | kyshtovka
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kyshtovka&units=imperial
# Processing Record 15 of Set 2 | kutum
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kutum&units=imperial
# Processing Record 16 of Set 2 | altar
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=altar&units=imperial
# Processing Record 17 of Set 2 | south venice
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=south venice&units=imperial
# Processing Record 18 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=east london&units=imperial
# Processing Record 19 of Set 2 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=katsuura&units=imperial
# Processing Record 20 of Set 2 | amarillo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=amarillo&units=imperial
# City not found... Skipping taolanaro
# Processing Record 21 of Set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=atuona&units=imperial
# City not found... Skipping saleaula
# Processing Record 22 of Set 2 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=dikson&units=imperial
# Processing Record 23 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint george&units=imperial
# Processing Record 24 of Set 2 | xining
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=xining&units=imperial
# Processing Record 25 of Set 2 | igrim
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=igrim&units=imperial
# Processing Record 26 of Set 2 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=chokurdakh&units=imperial
# Processing Record 27 of Set 2 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tilichiki&units=imperial
# Processing Record 28 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=qaanaaq&units=imperial
# Processing Record 29 of Set 2 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=longyearbyen&units=imperial
# Processing Record 30 of Set 2 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=klaksvik&units=imperial
# Processing Record 31 of Set 2 | port keats
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port keats&units=imperial
# Processing Record 32 of Set 2 | saint andrews
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint andrews&units=imperial
# Processing Record 33 of Set 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kodiak&units=imperial
# Processing Record 34 of Set 2 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rikitea&units=imperial
# Processing Record 35 of Set 2 | mugango
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mugango&units=imperial
# Processing Record 36 of Set 2 | macroom
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=macroom&units=imperial
# City not found... Skipping andevoranto
# Processing Record 37 of Set 2 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=abu dhabi&units=imperial
# Processing Record 38 of Set 2 | luanda
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=luanda&units=imperial
# Processing Record 39 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=busselton&units=imperial
# City not found... Skipping belushya guba
# Processing Record 40 of Set 2 | oksfjord
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=oksfjord&units=imperial
# Processing Record 41 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tasiilaq&units=imperial
# Processing Record 42 of Set 2 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=iqaluit&units=imperial
# Processing Record 43 of Set 2 | ambanja
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ambanja&units=imperial
# Processing Record 44 of Set 2 | royan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=royan&units=imperial
# Processing Record 45 of Set 2 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ushuaia&units=imperial
# Processing Record 46 of Set 2 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hithadhoo&units=imperial
# Processing Record 47 of Set 2 | malakal
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=malakal&units=imperial
# Processing Record 48 of Set 2 | orapa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=orapa&units=imperial
# City not found... Skipping vaitupu
# Processing Record 49 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=punta arenas&units=imperial
# Processing Record 50 of Set 2 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vila velha&units=imperial
# Processing Record 1 of Set 3 | ahvaz
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ahvaz&units=imperial
# Processing Record 2 of Set 3 | nome
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nome&units=imperial
# Processing Record 3 of Set 3 | kokoda
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kokoda&units=imperial
# Processing Record 4 of Set 3 | shangrao
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=shangrao&units=imperial
# Processing Record 5 of Set 3 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=leningradskiy&units=imperial
# Processing Record 6 of Set 3 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=isangel&units=imperial
# Processing Record 7 of Set 3 | sistranda
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sistranda&units=imperial
# Processing Record 8 of Set 3 | kuching
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kuching&units=imperial
# Processing Record 9 of Set 3 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ilulissat&units=imperial
# Processing Record 10 of Set 3 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=faanui&units=imperial
# Processing Record 11 of Set 3 | sola
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sola&units=imperial
# Processing Record 12 of Set 3 | calvinia
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=calvinia&units=imperial
# Processing Record 13 of Set 3 | nizhniy tsasuchey
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nizhniy tsasuchey&units=imperial
# Processing Record 14 of Set 3 | crotone
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=crotone&units=imperial
# Processing Record 15 of Set 3 | teknaf
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=teknaf&units=imperial
# Processing Record 16 of Set 3 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=beringovskiy&units=imperial
# Processing Record 17 of Set 3 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=torbay&units=imperial
# Processing Record 18 of Set 3 | rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rio grande&units=imperial
# Processing Record 19 of Set 3 | sakaiminato
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sakaiminato&units=imperial
# Processing Record 20 of Set 3 | maragogi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=maragogi&units=imperial
# Processing Record 21 of Set 3 | biltine
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=biltine&units=imperial
# City not found... Skipping sentyabrskiy
# Processing Record 22 of Set 3 | naze
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=naze&units=imperial
# Processing Record 23 of Set 3 | phan thiet
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=phan thiet&units=imperial
# Processing Record 24 of Set 3 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=chuy&units=imperial
# Processing Record 25 of Set 3 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint-augustin&units=imperial
# Processing Record 26 of Set 3 | krasnoarmeysk
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=krasnoarmeysk&units=imperial
# Processing Record 27 of Set 3 | axim
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=axim&units=imperial
# Processing Record 28 of Set 3 | goundam
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=goundam&units=imperial
# Processing Record 29 of Set 3 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bredasdorp&units=imperial
# Processing Record 30 of Set 3 | minot
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=minot&units=imperial
# Processing Record 31 of Set 3 | bilma
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bilma&units=imperial
# Processing Record 32 of Set 3 | bodden town
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bodden town&units=imperial
# Processing Record 33 of Set 3 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=plettenberg bay&units=imperial
# Processing Record 34 of Set 3 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=deputatskiy&units=imperial
# Processing Record 35 of Set 3 | tura
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tura&units=imperial
# Processing Record 36 of Set 3 | boa vista
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=boa vista&units=imperial
# Processing Record 37 of Set 3 | parsons
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=parsons&units=imperial
# Processing Record 38 of Set 3 | champerico
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=champerico&units=imperial
# Processing Record 39 of Set 3 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hasaki&units=imperial
# Processing Record 40 of Set 3 | ushtobe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ushtobe&units=imperial
# Processing Record 41 of Set 3 | duobao
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=duobao&units=imperial
# Processing Record 42 of Set 3 | requena
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=requena&units=imperial
# Processing Record 43 of Set 3 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=geraldton&units=imperial
# Processing Record 44 of Set 3 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kapaa&units=imperial
# Processing Record 45 of Set 3 | alyangula
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=alyangula&units=imperial
# Processing Record 46 of Set 3 | muros
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=muros&units=imperial
# Processing Record 47 of Set 3 | beyneu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=beyneu&units=imperial
# Processing Record 48 of Set 3 | shache
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=shache&units=imperial
# Processing Record 49 of Set 3 | san borja
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=san borja&units=imperial
# Processing Record 50 of Set 3 | chico
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=chico&units=imperial
# Processing Record 1 of Set 4 | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=constitucion&units=imperial
# Processing Record 2 of Set 4 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ishigaki&units=imperial
# Processing Record 3 of Set 4 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=khatanga&units=imperial
# Processing Record 4 of Set 4 | vysokogornyy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vysokogornyy&units=imperial
# Processing Record 5 of Set 4 | vostok
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vostok&units=imperial
# City not found... Skipping grand river south east
# Processing Record 6 of Set 4 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hervey bay&units=imperial
# Processing Record 7 of Set 4 | ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ahipara&units=imperial
# Processing Record 8 of Set 4 | siguiri
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=siguiri&units=imperial
# Processing Record 9 of Set 4 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hamilton&units=imperial
# Processing Record 10 of Set 4 | aketi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=aketi&units=imperial
# Processing Record 11 of Set 4 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=touros&units=imperial
# Processing Record 12 of Set 4 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port lincoln&units=imperial
# Processing Record 13 of Set 4 | rengo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rengo&units=imperial
# Processing Record 14 of Set 4 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=butaritari&units=imperial
# Processing Record 15 of Set 4 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port macquarie&units=imperial
# Processing Record 16 of Set 4 | brokopondo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=brokopondo&units=imperial
# Processing Record 17 of Set 4 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=san cristobal&units=imperial
# Processing Record 18 of Set 4 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=guerrero negro&units=imperial
# Processing Record 19 of Set 4 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lebu&units=imperial
# Processing Record 20 of Set 4 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cherskiy&units=imperial
# Processing Record 21 of Set 4 | miri
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=miri&units=imperial
# Processing Record 22 of Set 4 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=talnakh&units=imperial
# Processing Record 23 of Set 4 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=carnarvon&units=imperial
# Processing Record 24 of Set 4 | baicheng
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=baicheng&units=imperial
# Processing Record 25 of Set 4 | baghdad
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=baghdad&units=imperial
# Processing Record 26 of Set 4 | bucksport
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bucksport&units=imperial
# Processing Record 27 of Set 4 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rio gallegos&units=imperial
# Processing Record 28 of Set 4 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sur&units=imperial
# Processing Record 29 of Set 4 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=valparaiso&units=imperial
# Processing Record 30 of Set 4 | saint-felicien
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint-felicien&units=imperial
# Processing Record 31 of Set 4 | gwadar
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=gwadar&units=imperial
# Processing Record 32 of Set 4 | nassau
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nassau&units=imperial
# Processing Record 33 of Set 4 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bethel&units=imperial
# Processing Record 34 of Set 4 | broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=broken hill&units=imperial
# Processing Record 35 of Set 4 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=alta floresta&units=imperial
# Processing Record 36 of Set 4 | kupang
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kupang&units=imperial
# Processing Record 37 of Set 4 | gizo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=gizo&units=imperial
# Processing Record 38 of Set 4 | staryy nadym
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=staryy nadym&units=imperial
# Processing Record 39 of Set 4 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kaitangata&units=imperial
# Processing Record 40 of Set 4 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=barrow&units=imperial
# Processing Record 41 of Set 4 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=georgetown&units=imperial
# Processing Record 42 of Set 4 | terney
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=terney&units=imperial
# Processing Record 43 of Set 4 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=castro&units=imperial
# Processing Record 44 of Set 4 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=codrington&units=imperial
# City not found... Skipping tumannyy
# Processing Record 45 of Set 4 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saskylakh&units=imperial
# Processing Record 46 of Set 4 | killarney
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=killarney&units=imperial
# Processing Record 47 of Set 4 | port hedland
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port hedland&units=imperial
# Processing Record 48 of Set 4 | kirakira
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kirakira&units=imperial
# Processing Record 49 of Set 4 | hay river
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hay river&units=imperial
# Processing Record 50 of Set 4 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ponta do sol&units=imperial
# Processing Record 1 of Set 5 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=norman wells&units=imperial
# Processing Record 2 of Set 5 | turan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=turan&units=imperial
# Processing Record 3 of Set 5 | carlos antonio lopez
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=carlos antonio lopez&units=imperial
# Processing Record 4 of Set 5 | talcahuano
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=talcahuano&units=imperial
# Processing Record 5 of Set 5 | kumluca
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kumluca&units=imperial
# Processing Record 6 of Set 5 | salalah
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=salalah&units=imperial
# Processing Record 7 of Set 5 | sabang
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sabang&units=imperial
# Processing Record 8 of Set 5 | kikwit
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kikwit&units=imperial
# Processing Record 9 of Set 5 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cidreira&units=imperial
# Processing Record 10 of Set 5 | kieta
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kieta&units=imperial
# Processing Record 11 of Set 5 | kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kununurra&units=imperial
# Processing Record 12 of Set 5 | domoni
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=domoni&units=imperial
# Processing Record 13 of Set 5 | skole
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=skole&units=imperial
# City not found... Skipping jubayl
# Processing Record 14 of Set 5 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint-philippe&units=imperial
# Processing Record 15 of Set 5 | yumen
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=yumen&units=imperial
# Processing Record 16 of Set 5 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=los llanos de aridane&units=imperial
# Processing Record 17 of Set 5 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sinnamary&units=imperial
# Processing Record 18 of Set 5 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=severo-kurilsk&units=imperial
# Processing Record 19 of Set 5 | ndola
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ndola&units=imperial
# Processing Record 20 of Set 5 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=esperance&units=imperial
# Processing Record 21 of Set 5 | yulara
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=yulara&units=imperial
# Processing Record 22 of Set 5 | luancheng
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=luancheng&units=imperial
# City not found... Skipping formoso do araguaia
# Processing Record 23 of Set 5 | xai-xai
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=xai-xai&units=imperial
# Processing Record 24 of Set 5 | baraki barak
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=baraki barak&units=imperial
# Processing Record 25 of Set 5 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mar del plata&units=imperial
# Processing Record 26 of Set 5 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=coquimbo&units=imperial
# Processing Record 27 of Set 5 | hudson bay
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hudson bay&units=imperial
# City not found... Skipping utiroa
# Processing Record 28 of Set 5 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=caravelas&units=imperial
# Processing Record 29 of Set 5 | khor
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=khor&units=imperial
# Processing Record 30 of Set 5 | lakatoro
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lakatoro&units=imperial
# Processing Record 31 of Set 5 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=portland&units=imperial
# Processing Record 32 of Set 5 | sangar
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sangar&units=imperial
# Processing Record 33 of Set 5 | miraflores
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=miraflores&units=imperial
# Processing Record 34 of Set 5 | sri aman
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sri aman&units=imperial
# Processing Record 35 of Set 5 | galveston
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=galveston&units=imperial
# Processing Record 36 of Set 5 | marfino
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=marfino&units=imperial
# Processing Record 37 of Set 5 | aqtobe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=aqtobe&units=imperial
# Processing Record 38 of Set 5 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=walvis bay&units=imperial
# Processing Record 39 of Set 5 | waitara
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=waitara&units=imperial
# Processing Record 40 of Set 5 | alzey
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=alzey&units=imperial
# Processing Record 41 of Set 5 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint-georges&units=imperial
# Processing Record 42 of Set 5 | berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=berlevag&units=imperial
# Processing Record 43 of Set 5 | latur
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=latur&units=imperial
# Processing Record 44 of Set 5 | sawankhalok
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sawankhalok&units=imperial
# Processing Record 45 of Set 5 | martinsville
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=martinsville&units=imperial
# Processing Record 46 of Set 5 | amapa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=amapa&units=imperial
# Processing Record 47 of Set 5 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=pevek&units=imperial
# Processing Record 48 of Set 5 | dunda
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=dunda&units=imperial
# Processing Record 49 of Set 5 | karlskoga
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=karlskoga&units=imperial
# Processing Record 50 of Set 5 | west bay
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=west bay&units=imperial
# Processing Record 1 of Set 6 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ust-nera&units=imperial
# City not found... Skipping el balyana
# Processing Record 2 of Set 6 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=provideniya&units=imperial
# Processing Record 3 of Set 6 | riohacha
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=riohacha&units=imperial
# Processing Record 4 of Set 6 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port elizabeth&units=imperial
# Processing Record 5 of Set 6 | manali
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=manali&units=imperial
# Processing Record 6 of Set 6 | saint-raphael
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint-raphael&units=imperial
# Processing Record 7 of Set 6 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ketchikan&units=imperial
# Processing Record 8 of Set 6 | peceneaga
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=peceneaga&units=imperial
# Processing Record 9 of Set 6 | mount isa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mount isa&units=imperial
# Processing Record 10 of Set 6 | haines junction
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=haines junction&units=imperial
# Processing Record 11 of Set 6 | necochea
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=necochea&units=imperial
# City not found... Skipping palabuhanratu
# Processing Record 12 of Set 6 | atambua
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=atambua&units=imperial
# Processing Record 13 of Set 6 | huittinen
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=huittinen&units=imperial
# Processing Record 14 of Set 6 | colonia
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=colonia&units=imperial
# Processing Record 15 of Set 6 | kadoma
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kadoma&units=imperial
# Processing Record 16 of Set 6 | bonavista
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bonavista&units=imperial
# Processing Record 17 of Set 6 | college
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=college&units=imperial
# Processing Record 18 of Set 6 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lompoc&units=imperial
# Processing Record 19 of Set 6 | itaguai
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=itaguai&units=imperial
# Processing Record 20 of Set 6 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kruisfontein&units=imperial
# Processing Record 21 of Set 6 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ulladulla&units=imperial
# Processing Record 22 of Set 6 | florida
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=florida&units=imperial
# Processing Record 23 of Set 6 | qarayeri
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=qarayeri&units=imperial
# Processing Record 24 of Set 6 | laramie
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=laramie&units=imperial
# Processing Record 25 of Set 6 | poum
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=poum&units=imperial
# Processing Record 26 of Set 6 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ugoofaaru&units=imperial
# Processing Record 27 of Set 6 | arlit
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=arlit&units=imperial
# City not found... Skipping scalloway
# Processing Record 28 of Set 6 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lorengau&units=imperial
# Processing Record 29 of Set 6 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sisimiut&units=imperial
# Processing Record 30 of Set 6 | sandwick
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sandwick&units=imperial
# Processing Record 31 of Set 6 | iwanai
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=iwanai&units=imperial
# Processing Record 32 of Set 6 | kokstad
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kokstad&units=imperial
# Processing Record 33 of Set 6 | karratha
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=karratha&units=imperial
# Processing Record 34 of Set 6 | tallahassee
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tallahassee&units=imperial
# City not found... Skipping vreed en hoop
# Processing Record 35 of Set 6 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cap malheureux&units=imperial
# City not found... Skipping warqla
# Processing Record 36 of Set 6 | noumea
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=noumea&units=imperial
# Processing Record 37 of Set 6 | savannah bight
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=savannah bight&units=imperial
# Processing Record 38 of Set 6 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=petropavlovsk-kamchatskiy&units=imperial
# Processing Record 39 of Set 6 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tiksi&units=imperial
# Processing Record 40 of Set 6 | buta
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=buta&units=imperial
# Processing Record 41 of Set 6 | lindenberg
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lindenberg&units=imperial
# Processing Record 42 of Set 6 | otane
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=otane&units=imperial
# Processing Record 43 of Set 6 | tessalit
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tessalit&units=imperial
# Processing Record 44 of Set 6 | balotra
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=balotra&units=imperial
# Processing Record 45 of Set 6 | avera
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=avera&units=imperial
# Processing Record 46 of Set 6 | teahupoo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=teahupoo&units=imperial
# City not found... Skipping paradwip
# Processing Record 47 of Set 6 | alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=alice springs&units=imperial
# Processing Record 48 of Set 6 | floriano
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=floriano&units=imperial
# City not found... Skipping rawannawi
# Processing Record 49 of Set 6 | miyang
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=miyang&units=imperial
# City not found... Skipping mys shmidta
# Processing Record 50 of Set 6 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=udachnyy&units=imperial
# Processing Record 1 of Set 7 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sao felix do xingu&units=imperial
# Processing Record 2 of Set 7 | sokur
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sokur&units=imperial
# Processing Record 3 of Set 7 | beloha
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=beloha&units=imperial
# City not found... Skipping saryshagan
# Processing Record 4 of Set 7 | hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hualmay&units=imperial
# Processing Record 5 of Set 7 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=leshukonskoye&units=imperial
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vrangel&units=imperial
# Processing Record 13 of Set 10 | cascais
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cascais&units=imperial
# Processing Record 14 of Set 10 | dedougou
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=dedougou&units=imperial
# Processing Record 15 of Set 10 | iquique
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=iquique&units=imperial
# Processing Record 16 of Set 10 | hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hambantota&units=imperial
# Processing Record 17 of Set 10 | vondrozo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vondrozo&units=imperial
# Processing Record 18 of Set 10 | san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=san quintin&units=imperial
# Processing Record 19 of Set 10 | ilinskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ilinskiy&units=imperial
# Processing Record 20 of Set 10 | marawi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=marawi&units=imperial
# Processing Record 21 of Set 10 | miyazu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=miyazu&units=imperial
# Processing Record 22 of Set 10 | lafia
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lafia&units=imperial
# Processing Record 23 of Set 10 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=antofagasta&units=imperial
# Processing Record 24 of Set 10 | erenhot
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=erenhot&units=imperial
# Processing Record 25 of Set 10 | kiama
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kiama&units=imperial
# Processing Record 26 of Set 10 | santona
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=santona&units=imperial
# Processing Record 27 of Set 10 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=krasnoselkup&units=imperial
# Processing Record 28 of Set 10 | nizhniy ingash
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=nizhniy ingash&units=imperial
# Processing Record 29 of Set 10 | muisne
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=muisne&units=imperial
# Processing Record 30 of Set 10 | imeni zhelyabova
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=imeni zhelyabova&units=imperial
# Processing Record 31 of Set 10 | polis
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=polis&units=imperial
# Processing Record 32 of Set 10 | roma
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=roma&units=imperial
# Processing Record 33 of Set 10 | the village
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=the village&units=imperial
# Processing Record 34 of Set 10 | bethanien
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bethanien&units=imperial
# Processing Record 35 of Set 10 | wuzhou
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=wuzhou&units=imperial
# Processing Record 36 of Set 10 | maple creek
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=maple creek&units=imperial
# Processing Record 37 of Set 10 | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=la ronge&units=imperial
# Processing Record 38 of Set 10 | shelburne
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=shelburne&units=imperial
# Processing Record 39 of Set 10 | rinteln
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=rinteln&units=imperial
# Processing Record 40 of Set 10 | huaiyuan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=huaiyuan&units=imperial
# Processing Record 41 of Set 10 | tepeapulco
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tepeapulco&units=imperial
# Processing Record 42 of Set 10 | sao luiz gonzaga
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sao luiz gonzaga&units=imperial
# Processing Record 43 of Set 10 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=grand gaube&units=imperial
# Processing Record 44 of Set 10 | teya
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=teya&units=imperial
# Processing Record 45 of Set 10 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=san policarpo&units=imperial
# Processing Record 46 of Set 10 | westport
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=westport&units=imperial
# Processing Record 47 of Set 10 | omboue
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=omboue&units=imperial
# Processing Record 48 of Set 10 | wewak
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=wewak&units=imperial
# Processing Record 49 of Set 10 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=strezhevoy&units=imperial
# Processing Record 50 of Set 10 | potsdam
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=potsdam&units=imperial
# Processing Record 1 of Set 11 | paluan
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=paluan&units=imperial
# Processing Record 2 of Set 11 | krasnyy chikoy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=krasnyy chikoy&units=imperial
# Processing Record 3 of Set 11 | iralaya
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=iralaya&units=imperial
# Processing Record 4 of Set 11 | tanggu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tanggu&units=imperial
# Processing Record 5 of Set 11 | puerto el triunfo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=puerto el triunfo&units=imperial
# Processing Record 6 of Set 11 | charters towers
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=charters towers&units=imperial
# Processing Record 7 of Set 11 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sao jose da coroa grande&units=imperial
# City not found... Skipping sorvag
# Processing Record 8 of Set 11 | mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mehamn&units=imperial
# Processing Record 9 of Set 11 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=saint-joseph&units=imperial
# Processing Record 10 of Set 11 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=batticaloa&units=imperial
# Processing Record 11 of Set 11 | lockport
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lockport&units=imperial
# Processing Record 12 of Set 11 | bachaquero
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bachaquero&units=imperial
# Processing Record 13 of Set 11 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=yar-sale&units=imperial
# Processing Record 14 of Set 11 | duzce
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=duzce&units=imperial
# Processing Record 15 of Set 11 | shirokiy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=shirokiy&units=imperial
# Processing Record 16 of Set 11 | namatanai
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=namatanai&units=imperial
# Processing Record 17 of Set 11 | bubaque
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bubaque&units=imperial
# Processing Record 18 of Set 11 | taltal
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=taltal&units=imperial
# Processing Record 19 of Set 11 | aitape
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=aitape&units=imperial
# Processing Record 20 of Set 11 | staroye drozhzhanoye
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=staroye drozhzhanoye&units=imperial
# Processing Record 21 of Set 11 | santa fe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=santa fe&units=imperial
# Processing Record 22 of Set 11 | trairi
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=trairi&units=imperial
# Processing Record 23 of Set 11 | sao miguel do tapuio
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=sao miguel do tapuio&units=imperial
# Processing Record 24 of Set 11 | manaquiri
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=manaquiri&units=imperial
# Processing Record 25 of Set 11 | olinda
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=olinda&units=imperial
# City not found... Skipping aflu
# City not found... Skipping miranorte
# Processing Record 26 of Set 11 | barcelos
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=barcelos&units=imperial
# Processing Record 27 of Set 11 | newport
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=newport&units=imperial
# Processing Record 28 of Set 11 | narrabri
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=narrabri&units=imperial
# Processing Record 29 of Set 11 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=mitsamiouli&units=imperial
# Processing Record 30 of Set 11 | goma
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=goma&units=imperial
# Processing Record 31 of Set 11 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ambilobe&units=imperial
# Processing Record 32 of Set 11 | dwarka
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=dwarka&units=imperial
# Processing Record 33 of Set 11 | oistins
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=oistins&units=imperial
# Processing Record 34 of Set 11 | kasangulu
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kasangulu&units=imperial
# Processing Record 35 of Set 11 | gat
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=gat&units=imperial
# Processing Record 36 of Set 11 | bosaso
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=bosaso&units=imperial
# Processing Record 37 of Set 11 | guozhen
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=guozhen&units=imperial
# Processing Record 38 of Set 11 | ishige
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=ishige&units=imperial
# Processing Record 39 of Set 11 | pochutla
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=pochutla&units=imperial
# Processing Record 40 of Set 11 | copiapo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=copiapo&units=imperial
# City not found... Skipping lolua
# Processing Record 41 of Set 11 | laredo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=laredo&units=imperial
# City not found... Skipping cagayan de tawi-tawi
# Processing Record 42 of Set 11 | arman
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=arman&units=imperial
# Processing Record 43 of Set 11 | port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port hardy&units=imperial
# Processing Record 44 of Set 11 | garissa
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=garissa&units=imperial
# Processing Record 45 of Set 11 | venice
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=venice&units=imperial
# Processing Record 46 of Set 11 | coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=coihaique&units=imperial
# Processing Record 47 of Set 11 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=dunedin&units=imperial
# Processing Record 48 of Set 11 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=marsh harbour&units=imperial
# Processing Record 49 of Set 11 | urucara
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=urucara&units=imperial
# Processing Record 50 of Set 11 | kochubey
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=kochubey&units=imperial
# Processing Record 1 of Set 12 | cuamba
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=cuamba&units=imperial
# Processing Record 2 of Set 12 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=clyde river&units=imperial
# Processing Record 3 of Set 12 | lingao
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=lingao&units=imperial
# Processing Record 4 of Set 12 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vardo&units=imperial
# Processing Record 5 of Set 12 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=vestmanna&units=imperial
# City not found... Skipping khonuu
# Processing Record 6 of Set 12 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port-gentil&units=imperial
# Processing Record 7 of Set 12 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=batagay-alyta&units=imperial
# Processing Record 8 of Set 12 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=qasigiannguit&units=imperial
# Processing Record 9 of Set 12 | alihe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=alihe&units=imperial
# Processing Record 10 of Set 12 | port moresby
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=port moresby&units=imperial
# Processing Record 11 of Set 12 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=luderitz&units=imperial
# Processing Record 12 of Set 12 | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=hofn&units=imperial
# Processing Record 13 of Set 12 | tefe
# http://api.openweathermap.org/data/2.5/weather?appid=a967d36dec1a79215b05e18771f66619&q=tefe&units=imperial

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create city data frame
city_df = pd.DataFrame({"City" : city,
                       "Cloudiness" : cloudiness,
                       "Country" : country,
                       "Date" : date,
                       "Humidity" : humidity,
                       "Lat" : lat,
                       "Lng" : lng,
                       "Max Temp" : max_temp,
                       "Wind Speed" : wind_speed})

city_df.count()
# Out:
# City          563
# Cloudiness    563
# Country       563
# Date          563
# Humidity      563
# Lat           563
# Lng           563
# Max Temp      563
# Wind Speed    563
# dtype: int64

# %%
#export to csv file
output_file = os.path.join(output_dir[0], output_dir[1])
city_df.to_csv(output_file, index=True)

# %%
city_df
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Gorom-Gorom         100      BF  1604462328        26  14.44   -0.24
# 1          Avarua         100      CK  1604461833        78 -21.21 -159.78
# 2         Mataura          42      NZ  1604461798        55 -46.19  168.86
# 3       Mahébourg          40      MU  1604461587        64 -20.41   57.70
# 4          Sorong         100      ID  1604462328        81  -0.88  131.25
# ..            ...         ...     ...         ...       ...    ...     ...
# 558         Alihe         100      CN  1604462989        73  50.57  123.72
# 559  Port Moresby          40      PG  1604462989        62  -9.44  147.18
# 560      Lüderitz           8      NA  1604462586        95 -26.65   15.16
# 561          Hofn         100      IS  1604462989        63  64.25  -15.21
# 562          Tefé          56      BR  1604462989        93  -3.35  -64.71
#
#      Max Temp  Wind Speed
# 0       81.00        7.05
# 1       75.20       26.22
# 2       66.99        8.01
# 3       73.40        8.05
# 4       82.36       11.39
# ..        ...         ...
# 558     26.69        5.70
# 559     87.80       11.41
# 560     57.52        6.82
# 561     43.34        6.82
# 562     74.97        2.46
#
# [563 rows x 9 columns]

# %%
city_df.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  563.000000  5.630000e+02  563.000000  563.000000  563.000000
# mean    50.857904  1.604463e+09   71.468917   18.694494   18.967567
# std     40.167280  3.253102e+02   21.172239   33.701162   91.912566
# min      0.000000  1.604461e+09    2.000000  -54.800000 -179.170000
# 25%      3.500000  1.604462e+09   58.500000   -9.700000  -63.810000
# 50%     51.000000  1.604463e+09   77.000000   20.890000   22.700000
# 75%     90.000000  1.604463e+09   87.000000   47.780000  108.160000
# max    100.000000  1.604463e+09  100.000000   78.220000  179.320000
#
#          Max Temp  Wind Speed
# count  563.000000  563.000000
# mean    58.236412    8.434885
# std     22.929388    6.587985
# min    -20.200000    0.200000
# 25%     44.600000    3.635000
# 50%     62.600000    6.930000
# 75%     77.090000   11.340000
# max    100.400000   61.850000

# %% [markdown]
# **Remove cities where Humidity > 100%**
# Not necessary if there are no cities with Humidity > 100%

# %%
humid_cities = city_df["City"].loc[city_df["Humidity"] > 100].count()
if humid_cities > 0:
    city_df = city_df.loc[city_df["Humidity"] <= 100]
city_df
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Gorom-Gorom         100      BF  1604462328        26  14.44   -0.24
# 1          Avarua         100      CK  1604461833        78 -21.21 -159.78
# 2         Mataura          42      NZ  1604461798        55 -46.19  168.86
# 3       Mahébourg          40      MU  1604461587        64 -20.41   57.70
# 4          Sorong         100      ID  1604462328        81  -0.88  131.25
# ..            ...         ...     ...         ...       ...    ...     ...
# 558         Alihe         100      CN  1604462989        73  50.57  123.72
# 559  Port Moresby          40      PG  1604462989        62  -9.44  147.18
# 560      Lüderitz           8      NA  1604462586        95 -26.65   15.16
# 561          Hofn         100      IS  1604462989        63  64.25  -15.21
# 562          Tefé          56      BR  1604462989        93  -3.35  -64.71
#
#      Max Temp  Wind Speed
# 0       81.00        7.05
# 1       75.20       26.22
# 2       66.99        8.01
# 3       73.40        8.05
# 4       82.36       11.39
# ..        ...         ...
# 558     26.69        5.70
# 559     87.80       11.41
# 560     57.52        6.82
# 561     43.34        6.82
# 562     74.97        2.46
#
# [563 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# create a scatter plot latitude v temperature
from datetime import datetime
dt = int(date[0])
plot_date = datetime.fromtimestamp(dt).strftime('%y/%m/%d')
x_lat = city_df['Lat']
y_temp = city_df['Max Temp']
fig, ax = plt.subplots(figsize=(7,7))
ax.set_autoscale_on(True)
ax.scatter(x_lat, y_temp)
plt.title(f"City Latitude vs Max Temperature ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_temp.png")
plt.savefig(file)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
y_hum = city_df["Humidity"]

fig, ax1 = plt.subplots(figsize=(7,7))
ax1.set_autoscale_on(True)
ax1.scatter(x_lat, y_hum)
plt.title(f"City Latitude vs Humidity ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_humid.png")
plt.savefig(file)

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
y_cloud = city_df["Cloudiness"]
fig, ax2 = plt.subplots(figsize=(7,7))
ax2.set_autoscale_on(True)
ax2.scatter(x_lat, y_cloud)
plt.title(f"City Latitude vs Cloudiness ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_cloud.png")
plt.savefig(file)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
y_wind = city_df["Wind Speed"]
fig, ax3 = plt.subplots(figsize=(7,7))
ax3.set_autoscale_on(True)
ax3.scatter(x_lat, y_wind)
plt.title(f"City Latitude vs Wind Speed ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
#plt.show()
file = os.path.join("images", "lat_wind.png")
plt.savefig(file)

# %% [markdown]
# **Linear Regression

# %%
# dependencies
import scipy.stats as st

# %%
north_df = city_df[city_df["Lat"] >= 0]
north_df
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Gorom-Gorom         100      BF  1604462328        26  14.44   -0.24
# 6         Araouane          83      ML  1604461842        17  18.90   -3.53
# 7         Thompson          90      CA  1604461837       100  55.74  -97.86
# 8          Cayenne          75      GF  1604462329       100   4.93  -52.33
# 11         Ziniaré          95      BF  1604462329        50  12.58   -1.30
# ..             ...         ...     ...         ...       ...    ...     ...
# 554      Vestmanna          90      FO  1604462988        65  62.16   -7.17
# 556  Batagay-Alyta          27      RU  1604462612        91  67.80  130.41
# 557  Qasigiannguit         100      GL  1604462989        86  68.82  -51.19
# 558          Alihe         100      CN  1604462989        73  50.57  123.72
# 561           Hofn         100      IS  1604462989        63  64.25  -15.21
#
#      Max Temp  Wind Speed
# 0       81.00        7.05
# 6       78.53        8.70
# 7       23.00        2.24
# 8       77.00        2.24
# 11      75.20        5.35
# ..        ...         ...
# 554     44.60       13.87
# 556     -1.48        1.23
# 557     33.80       16.11
# 558     26.69        5.70
# 561     43.34        6.82
#
# [369 rows x 9 columns]

# %%
south_df = city_df[city_df["Lat"] < 0]
south_df
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 1          Avarua         100      CK  1604461833        78 -21.21 -159.78
# 2         Mataura          42      NZ  1604461798        55 -46.19  168.86
# 3       Mahébourg          40      MU  1604461587        64 -20.41   57.70
# 4          Sorong         100      ID  1604462328        81  -0.88  131.25
# 5       Tuatapere          33      NZ  1604461580        55 -46.13  167.68
# ..            ...         ...     ...         ...       ...    ...     ...
# 550        Cuamba           1      MZ  1604462988        55 -14.80   36.54
# 555   Port-Gentil          33      GA  1604462988        82  -0.72    8.78
# 559  Port Moresby          40      PG  1604462989        62  -9.44  147.18
# 560      Lüderitz           8      NA  1604462586        95 -26.65   15.16
# 562          Tefé          56      BR  1604462989        93  -3.35  -64.71
#
#      Max Temp  Wind Speed
# 1       75.20       26.22
# 2       66.99        8.01
# 3       73.40        8.05
# 4       82.36       11.39
# 5       66.99        8.01
# ..        ...         ...
# 550     73.99        7.20
# 555     79.36        9.40
# 559     87.80       11.41
# 560     57.52        6.82
# 562     74.97        2.46
#
# [194 rows x 9 columns]

# %% [markdown]
# **Northern Hemisphere - Max Temperature vs Latitude

# %%
north_x_lat = north_df["Lat"]
north_y_temp = north_df["Max Temp"]

n_corr_coef = round(st.pearsonr(north_x_lat, north_y_temp)[0],2)
print(f"correlation coefficient: {n_corr_coef}")

n_temp = st.linregress(north_x_lat, north_y_temp)
print(f"The r-value is {n_temp.rvalue}")
# Out:
# correlation coefficient: -0.88
# The r-value is -0.8790645436766039

# %%
#create equation of line
line = n_slope * north_x_lat + n_intercept
line_eq = f"y = {round(n_slope,2)}x + {round(n_intercept,2)}"

# plot linear model on top of scatter plot
fig, ax = plt.subplots(figsize=(7,7))
ax.set_autoscale_on(True)
ax.scatter(north_x_lat, north_y_temp, marker='*', facecolors="green", edgecolors="green")
plt.plot(north_x_lat, line, 'b-')
plt.title(f"Northern Hemisphere - Max Temp vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.annotate(line_eq, (0,0), fontsize=12, color="blue")

file = os.path.join("images", "north_lat_temp.png")
plt.savefig(file)

# %% [markdown]
# **Southern Hemisphere - Max Temperature vs Latitude

# %%
south_x_lat = south_df["Lat"]
south_y_temp = south_df["Max Temp"]

s_corr_coef = round(st.pearsonr(south_x_lat, south_y_temp)[0],2)
print(f"correlation coefficient: {s_corr_coef}")

s_temp = st.linregress(south_x_lat, south_y_temp)
print(f"The r-value is {s_temp.rvalue}")
# Out:
# correlation coefficient: 0.53
# The r-value is 0.5317161383225176

# %%
#create equation of line
line = s_slope * south_x_lat + s_intercept
line_eq = f"y = {round(s_slope,2)}x + {round(s_intercept,2)}"

# plot linear model on top of scatter plot
fig, axs = plt.subplots(figsize=(7,7))
axs.set_autoscale_on(True)
axs.scatter(south_x_lat, south_y_temp, marker='*', facecolors="green", edgecolors="green")
plt.plot(south_x_lat, line, 'b-')
plt.title(f"Southern Hemisphere - Max Temp vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.annotate(line_eq, (-50,90), fontsize=12, color="blue")

file = os.path.join("images", "south_lat_temp.png")
plt.savefig(file)

# %% [markdown]
# **Northern Hemisphere - Humidity (%) vs Latitude

# %%
north_y_hum = north_df["Humidity"]

n_corr_coef = round(st.pearsonr(north_x_lat, north_y_hum)[0],2)
print(f"correlation coefficient: {n_corr_coef}")

n_humid = st.linregress(north_x_lat, north_y_hum)
print(f"The r-value is {n_humid.rvalue}")
# Out:
# correlation coefficient: 0.3
# The r-value is 0.29673601664136856

# %%
#create equation of line
line = n_slope * north_x_lat + n_intercept
line_eq = f"y = {round(n_slope,2)}x + {round(n_intercept,2)}"

# plot linear model on top of scatter plot
fig, nh = plt.subplots(figsize=(7,7))
nh.set_autoscale_on(True)
nh.scatter(north_x_lat, north_y_hum, marker='*', facecolors="green", edgecolors="green")
plt.plot(north_x_lat, line, 'b-')
plt.title(f"Northern Hemisphere - Humidity (%) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.annotate(line_eq, (0,0), fontsize=12, color="blue")

file = os.path.join("images", "north_lat_humid.png")
plt.savefig(file)

# %% [markdown]
# **Southern Hemisphere - Humidity (%) vs Latitude

# %%
south_y_hum = south_df["Humidity"]

s_corr_coef = round(st.pearsonr(south_x_lat, south_y_hum)[0],2)
print(f"correlation coefficient: {s_corr_coef}")

s_humid = st.linregress(south_x_lat, south_y_hum)
print(f"The r-value is {s_humid.rvalue}")
# Out:
# correlation coefficient: 0.12
# The r-value is 0.12442375099254133

# %%
#create equation of line
line = s_slope * south_x_lat + s_intercept
line_eq = f"y = {round(s_slope,2)}x + {round(s_intercept,2)}"

# plot linear model on top of scatter plot
fig, sh = plt.subplots(figsize=(7,7))
sh.set_autoscale_on(True)
sh.scatter(south_x_lat, south_y_hum, marker='*', facecolors="green", edgecolors="green")
plt.plot(south_x_lat, line, 'b-')
plt.title(f"Southern Hemisphere - Humidity (%) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.annotate(line_eq, (0,0), fontsize=12, color="blue")

file = os.path.join("images", "south_lat_humid.png")
plt.savefig(file)

# %% [markdown]
# **Northern Hemisphere - Cloudiness (%) vs Latitude

# %%
north_y_cloud = north_df["Cloudiness"]

n_corr_coef = round(st.pearsonr(north_x_lat, north_y_cloud)[0],2)
print(f"correlation coefficient: {n_corr_coef}")

north_cloud = st.linregress(north_x_lat, north_y_cloud)
print(f"The r-value is {north_cloud.rvalue}")
# Out:
# correlation coefficient: 0.16
# The r-value is 0.1646969155232774

# %%
#create equation of line
line = north_cloud.slope * north_x_lat + north_cloud.intercept
line_eq = f"y = {round(north_cloud.slope,2)}x + {round(north_cloud.intercept,2)}"

# plot linear model on top of scatter plot
fig, nc = plt.subplots(figsize=(7,7))
nc.set_autoscale_on(True)
nc.scatter(north_x_lat, north_y_cloud, marker='*', facecolors="green", edgecolors="green")
plt.plot(north_x_lat, line, 'b-')
plt.title(f"Northern Hemisphere - Cloudiness (%) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.annotate(line_eq, (0, 50), fontsize=12, color="blue")

file = os.path.join("images", "north_lat_cloud.png")
plt.savefig(file)

# %% [markdown]
# **Southern Hemisphere - Cloudiness (%) vs Latitude

# %%
south_y_cloud = south_df["Cloudiness"]

s_corr_coef = round(st.pearsonr(south_x_lat, south_y_cloud)[0],2)
print(f"correlation coefficient: {s_corr_coef}")

south_cloud = st.linregress(south_x_lat, south_y_cloud)
print(f"The r-value is {south_cloud.rvalue}")
# Out:
# correlation coefficient: 0.16
# The r-value is 0.16232283469112258

# %%
#create equation of line
line = south_cloud.slope * south_x_lat + south_cloud.intercept
line_eq = f"y = {round(south_cloud.slope,2)}x + {round(south_cloud.intercept,2)}"

# plot linear model on top of scatter plot
fig, nc = plt.subplots(figsize=(7,7))
nc.set_autoscale_on(True)
nc.scatter(south_x_lat, south_y_cloud, marker='*', facecolors="green", edgecolors="green")
plt.plot(south_x_lat, line, 'b-')
plt.title(f"Southern Hemisphere - Cloudiness (%) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.annotate(line_eq, (-55, 50), fontsize=12, color="blue")

file = os.path.join("images", "south_lat_cloud.png")
plt.savefig(file)
